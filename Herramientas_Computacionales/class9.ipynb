# %% [markdown]
# # Agenda:
#
# - [x] Actividad 35. Lea y ejecute la actividad de las notas en linux actualizadas.
# - [x] Configuracion del Ambiente de trabajo. Archivo `.bashr`.
#     - [x] Actividad 36. Lea y ejecute la actividad de las notas en linux actualizadas
#     - [x] Actividad 37. Lea y ejecute la actividad de las notas en linux actualizadas
#     - [x] Actividad 38. Lea y ejecute la actividad de las notas en linux actualizadas
# - []  Suspension de trabajos: comandos
#     - `top`
#     - `Ctrl+c`
#     - `Ctrl+z`
#     - `jobs`
#     - `bg`
#     - `kill`

# %% [markdown]
# primer comando `top`
# En clase se explico los encabezados del `top` .
#
# Comandos tratados en clase
#
# * `kill`
# * `ctrl-c`
# * `ctrl-z`
# * `fg`
# * `bg`
