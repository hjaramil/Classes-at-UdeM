# %% [markdown]
# ## Introduccion a Herramientas Computacionales.

# %% [markdown]
# # Linux (Unix)
# # SymPy
# # TikZ
#
# # Evaluacion:
# Esto es un laboratorio y casi todas las actividades las haremos aca. O sea que si falta, le toca traer excusa y ponerse al dia para la actividad de ese dia.
#
# # NO hay excusa para no hacer las tareas. Recursos:
#
# * Lo que ustedes saben
# * Google (casi que infinito).
# * ChatGPT
# * StackOverflow
# * Sus compañeros
# * Yo.
#
#
# ## Linux:
#
# * Es un sistema operativo. Lo vamos a aprender comandos y creamos shell scripts. Programas en lenguaje bash.
#
# * Origen: MIT (Massachusets Institute of Tecnology), Laboratorios Bell (ATT), General Electric, (en otras) se vieron en la necesitad de crear sistemas operativos que fueran multiusuario y multitarea. Inventaron el Unix.
# Los inventores de Laboratorios Bell fueron Ken Thomsom, Dennis Richie (este es el inventor de C). Luego se hizo una version en la Universidad de Berkely. Sistemas que usan Unix:
#     * Microsoft (Xenix)
#     * Hewlett Packard (HP)
#     * Apple (MacOS)
#     * Sun Microsystems (Solaris)
#
# Dentro de estos sistemas existen distintos tipos de unix.
# De todos ellos nosotros nos concentramos en Linux. Linus Torvads.
# Hay muchos sistemas Linux:
#     * Ubuntu (el que tenemos aca)
#     * Fedora
#     * CentOS.
#     * Red Hat dio origen a Fedora.
#     * OpenSUSE.
#
# ### Componentes de Linux:
# * Kernel: el manejo de memoria, de almacenamiento, y perifericos, etc.
# * Shell: Este la interface entre el usuario y el sistema operativo. El prompt de donde se ejecutan los comandos.
#
# ### Escritorios:
# En linux hay dos tipos. El KDE, se basa en QT (Quantum Technology)  y el GNOME que se basa n GTK: Gnome Toolkit.
# Aca tenemos el GNOME.
#
# ### Que vamos a hacer hoy
#
# * Crear un usuario
# * Explorar el sistema
#
#     * ```hostname``` : Devuelve el nombre de la maquina
#     * ```hostnamectl```: informacion mas detallada
#     * cat: concatenacion. Muestra el contenido de un archivo. ```cat \etc\os-release```
#
#     Si desea conocer el escritorio
#
#     ```>echo $XDG_CURRENT_DESKTOP```
#
#
# ### Comandos para conocer el sistema con prefijo ```ls```
#
# * ```lscpu```
# * ```lshw``` (lista hardware)
# * ```lsmem```
# * ```lsof``` lista de archivos abiertos.
# * ```lsub``` lista de dispositivos usb
#
#
# ## Estructura de archivos en Linux
# Hay dos tipos de archivos:
#
# * directorio (folder, rama)
# * archivo terminal (una hoja)

# %% [markdown]
# ## Comandos para conocer el sistema:
