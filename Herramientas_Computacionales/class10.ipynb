# %% [markdown]
# Muestre el alias util de `qjup` (matar todas las tareas en Jupyter).
# # Comandos útiles:
#
# * `bc` : born calculator
# * `who` : who is in the system
# * `date` :todays date
# * `which`: which executable is to run
# * `ssh`: secure shell. Manejo de redes. Otros comandos `telnet, rsh, ftp, ifconfig, iwconfig`.
# * `locate`: quick find on the system
# * `apt`: advance application toolkit
# * `watch`: watch a job that is running
# * `script`: record your activivies
# * `lpr`: print a file
# * `lpq`: watch the printing que
# * `lprm`: remove a job in the printing que.
# Estos se prueban en clase.

# %% [markdown]
# # Programacion basica en BASH (Born Again Shell)
#
# ## Elementos del la programacion (el orden no importa)
# * variables
# * instrucciones
#     * condicionales
#     * ciclos
