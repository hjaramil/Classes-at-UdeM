# %% [markdown]
# ### Actividad 6
#  El comando ```df``` ayuda a determinar el uso de los discos montados en el
# sistema. Encuentre, mediante el uso de este comando, como saber en que partición está
# su directorio home y qué pocentaje se está usando, también el uso en ```blocks```, el tamaño
# de cada block, y el espacio libre en ```blocks```.

# %% [markdown]
# ## El comando ```chown```: Change Owner (cambio de dueño).
#
#
# Cambiamos de duenho con el comando ```chown```. Ejempolo en clase
#
# Desarrollamos en clase las Actividades 6,7,8,9
#
# Hay dos tipos de direciones de archivos.
#
# * absoluta: siempre comienza con ```/```
# * relativa: no comienza con ```/```
#
#
# El comando ```stat``` es mas completo que el ```ls```.
# El comando ```file``` tambien da informacion que los otros no proveen.
#
# Al final usamos ```head```, ```tail```
