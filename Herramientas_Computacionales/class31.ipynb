# %% [markdown]
# # Matematica en `TikZ`.
# ## Aritmetica
# ## Trigonometria, exponencial y logaritmo
# Aca no vamos a hacer mucho, esto lo hacemos directamente en la terminal con un editor y compilando `TikZ`. Lamentablemente GoogleColab (basa en Jupyter) no soporta `TikZ'

# %% [markdown]
# ### Actividad \#1
# Escriba un script en `TikZ` que dibuja un triangulo rectangulo con vertices
# $(0,0), (4,0), (0,3)$. Use el teorema de Pitagoras para hallar la hipotenusa
# (usando \myTikZ) escriba el valor de la longitud de la hipotenusa sobre ella
# (hay que inclinarla), encuentre el angulo en el vertice $(4,0)$ y escribalo
# en la figura. Escriba los vertices como coordenadas. Ver figura abajo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Graficar funciones
# Se hicieron dos tipos de funciones
# * `plot`
# * `\addplot`, 'axis'
#
# ### Actividad #2
# Ponerle etiquetas a las dos funciones no etiquetadas en
# la grafica con parabola, funcion **seno** y **exponencial**. Estas dos ultimas son las que toca etiquetar.
#
# ## Graficas 3Dimensionales
#
# ### Actividad #3
# Asuma que usted es profesor de fisica y quiere ensenhar suma de vectores.
# Escoja dos vectores (numericos en 3D) y haga la suma de dos formas
#   * Por metodo del paralelogramo.
#   * El segundo comienza en la cabeza del primero. Se forma un triangulo,
#     el primero del origen a A, el segundo de A a B y la resultante del origen a B.
#     La suma se hace con \myTikZ. (usando `pgfmathsetmacro`).
