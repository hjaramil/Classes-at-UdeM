# %% [markdown]
# * uno
#     * A
#     * b
#     * c
# * dos
# * tres
#
# `Python`
# 1. UNO
# 2. DOS
# 3. Tres
#     1. A
#     2. b
#     3. c
#
# *italic*   **bold**
#
# Primera Columna |  Segunda Columna
# ----------------|-----------------
# $a_{11}$        |  $a_{12}$
# $a_{21}$   |  $a_{22}$
