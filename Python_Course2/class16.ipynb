# %% [markdown]
# # PANDAS: Python Data Analysis Library
# Ask [chatGPT](https://openai.com/blog/chatgpt) the following question:
# "can I say that PANDAS  (from Python) is a spreadsheet emulator?"
# Read the answer.
#
# ## From dictionary to dataframe
# La estructura de datos ```dictionary``` ya es conocida por nosotros.
#
# Pandas tiene dos estructuras de datos importantes.
#
# * Dataframe. En esta clase la examinamos
# * Series. Es unidimensional, es como una extension de los NumPY arrays.

# %%
from pandas import DataFrame

# construyamos un diccionario
Cars = {'Marca':['Honda Civic', 'Ford Focus', 'Toyota Corolla', 'Audi A4'], 
        'Precio':[88000, 84000, 100000, 120000],
        'Año':[2014, 2015, 2016, 2017],
        'Puertas':[2, 4, 4, 2]}

# convertimos el diccionario a un dataframe
dfCars = DataFrame(Cars, columns=['Marca', 'Precio', 'Año', 'Puertas'])
dfCars
# Out:
#             Marca  Precio   Año  Puertas
# 0     Honda Civic   88000  2014        2
# 1      Ford Focus   84000  2015        4
# 2  Toyota Corolla  100000  2016        4
# 3         Audi A4  120000  2017        2

# %% [markdown]
# ## Estadisticas basicas

# %%
dfCars[:3]  # slicing
# Out:
#             Marca  Precio   Año  Puertas
# 0     Honda Civic   88000  2014        2
# 1      Ford Focus   84000  2015        4
# 2  Toyota Corolla  100000  2016        4

# %%
 dfCars[:3].describe()
# Out:
#               Precio     Año   Puertas
# count       3.000000     3.0  3.000000
# mean    90666.666667  2015.0  3.333333
# std      8326.663998     1.0  1.154701
# min     84000.000000  2014.0  2.000000
# 25%     86000.000000  2014.5  3.000000
# 50%     88000.000000  2015.0  4.000000
# 75%     94000.000000  2015.5  4.000000
# max    100000.000000  2016.0  4.000000

# %%
dfCars[["Precio","Puertas"]].describe()
# Out:
#               Precio   Puertas
# count       4.000000  4.000000
# mean    98000.000000  3.000000
# std     16165.807537  1.154701
# min     84000.000000  2.000000
# 25%     87000.000000  2.000000
# 50%     94000.000000  3.000000
# 75%    105000.000000  4.000000
# max    120000.000000  4.000000

# %%
dfCars.iloc[:,2]  # todas las filas columna 2 (3)
# Out:
# 0    2014
# 1    2015
# 2    2016
# 3    2017
# Name: Año, dtype: int64

# %%
dfCars['Año']
# Out:
# 0    2014
# 1    2015
# 2    2016
# 3    2017
# Name: Año, dtype: int64

# %%
stats_price = dfCars['Precio'].describe()
stats_price
# Out:
# count         4.000000
# mean      98000.000000
# std       16165.807537
# min       84000.000000
# 25%       87000.000000
# 50%       94000.000000
# 75%      105000.000000
# max      120000.000000
# Name: Precio, dtype: float64

# %% [markdown]
# ## Four different ways to compute the mean

# %%
# directamente usando Pandas
mean = dfCars['Precio'].mean()
print("mean directly from the dataframe is", mean)

mean = stats_price[1]
print("mean from using arrays and pandas 'describe' ", mean)

# usando alphabetical keys
mean = stats_price['mean']
print("mean using pandas array with the key 'mean' ", mean)

# usando NumPY
import numpy as np
mean  = np.mean( dfCars['Precio'])
print("mean using NumPY", mean)
# Out:
# mean directly from the dataframe is 98000.0
# mean from using arrays and pandas 'describe'  98000.0
# mean using pandas array with the key 'mean'  98000.0
# mean using NumPY 98000.0

# %% [markdown]
# ## Slicing: Rebanar.
#
# Vamos a usar la sintaxis the ```numpy array```.  Solo dos indices.
#
# Syntaxis:
# ```
# A[:,:]   # todo
# A[:,1]  # la primera columna
# A[1,:]  # la primera fila
# A[a:b:c, e:f:d]  #desde la fila a hasta la b con incrementos de c
# # desde la columna e hasta la f con incrementos de d
# ```
#
# En Pandas se pueden usar ```keys```. Por ejemplo ```Precio```.

# %%
marcas = dfCars['Marca']
print(marcas)
# Out:
# 0       Honda Civic
# 1        Ford Focus
# 2    Toyota Corolla
# 3           Audi A4
# Name: Marca, dtype: object

# %%
df2 = marcas.to_string(index=False)
print(df2)
# Out:
#    Honda Civic
#     Ford Focus
# Toyota Corolla
#        Audi A4

# %%
marcas = dfCars.iloc[:, 0 ]  # la columna 0 (es la primera)
marcas
# Out:
# 0       Honda Civic
# 1        Ford Focus
# 2    Toyota Corolla
# 3           Audi A4
# Name: Marca, dtype: object

# %%
marcaPuertas = dfCars[["Marca", "Puertas"]]
marcaPuertas
# Out:
#             Marca  Puertas
# 0     Honda Civic        2
# 1      Ford Focus        4
# 2  Toyota Corolla        4
# 3         Audi A4        2

# %%
precioAPuertas = dfCars.loc[:, 'Precio': 'Puertas']
precioAPuertas
# Out:
#    Precio   Año  Puertas
# 0   88000  2014        2
# 1   84000  2015        4
# 2  100000  2016        4
# 3  120000  2017        2

# %%
precioAPuertas1 = dfCars.loc[1:2, 'Precio': 'Puertas']  # filas 1 a 2 inclusive (loc)
precioAPuertas1
# Out:
#    Precio   Año  Puertas
# 1   84000  2015        4
# 2  100000  2016        4

# %%
precioAPuertas1 = dfCars.iloc[1:2,:]  # filas 1 a 2 inclusive (loc)
precioAPuertas1
# Out:
#         Marca  Precio   Año  Puertas
# 1  Ford Focus   84000  2015        4

# %%
# puertas de Honda Civic
phc= dfCars.iloc[0,3]  #iloc es puramente numerico
phc
# Out:
# 2

# %%
# brincar por filas
dfCars.iloc[0:3:2, :]  # filas 0 hasta 2 con incrementos de 2, columnas todas
# Out:
#             Marca  Precio   Año  Puertas
# 0     Honda Civic   88000  2014        2
# 2  Toyota Corolla  100000  2016        4

# %%
dfCars.iloc[0,0]
# Out:
# 'Honda Civic'

# %%
dfCars.loc[0,'Marca']
# Out:
# 'Honda Civic'

# %%
# rango de columnas de la 0 a la 2
dfCars.iloc[:, 0:3]
# Out:
#             Marca  Precio   Año
# 0     Honda Civic   88000  2014
# 1      Ford Focus   84000  2015
# 2  Toyota Corolla  100000  2016
# 3         Audi A4  120000  2017

# %% [markdown]
# ## Seleccionamos filas

# %%
firstRow = dfCars.loc[0, :]
firstRow
# Out:
# Marca      Honda Civic
# Precio           88000
# Año               2014
# Puertas              2
# Name: 0, dtype: object

# %%
# filas 2 a la cuatro (de la primera a la tercera)
secondtoFourth = dfCars.loc[1:4, :]
secondtoFourth
# Out:
#             Marca  Precio   Año  Puertas
# 1      Ford Focus   84000  2015        4
# 2  Toyota Corolla  100000  2016        4
# 3         Audi A4  120000  2017        2

# %%
secondtoFourthc = dfCars.iloc[1:4, :]
secondtoFourthc
# Out:
#             Marca  Precio   Año  Puertas
# 1      Ford Focus   84000  2015        4
# 2  Toyota Corolla  100000  2016        4
# 3         Audi A4  120000  2017        2

# %% [markdown]
# ## subsets

# %%
toyToAudi = dfCars.iloc[1:3, 2:4]
3toyToAudi
# Out:
#     Año  Puertas
# 1  2015        4
# 2  2016        4

# %% [markdown]
# ## DataFrame Styling.
# Muchas de estas cosas las saque de ejemplos en la Web.
# "from 10 python tips and pandas stunning dataframe"
# Los modifique.

# %%
import pandas as pd

# colores de valores negativos
def color_negative_red(val):
    color = 'red' if val<0 else 'black'
    return 'color: %s' %color

df = pd.DataFrame( dict(col_1 = [1.53, -2.5, 3.53], 
                        col_2 = [-4.1, 5.9, 0 ]))

df.style.applymap(color_negative_red)
# Out:
# <style type="text/css">
# #T_2aa6e_row0_col0, #T_2aa6e_row1_col1, #T_2aa6e_row2_col0, #T_2aa6e_row2_col1 {
#   color: black;
# }
# #T_2aa6e_row0_col1, #T_2aa6e_row1_col0 {
#   color: red;
# }
# </style>
# <table id="T_2aa6e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2aa6e_level0_col0" class="col_heading level0 col0" >col_1</th>
#       <th id="T_2aa6e_level0_col1" class="col_heading level0 col1" >col_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2aa6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2aa6e_row0_col0" class="data row0 col0" >1.530000</td>
#       <td id="T_2aa6e_row0_col1" class="data row0 col1" >-4.100000</td>
#     </tr>
#     <tr>
#       <th id="T_2aa6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2aa6e_row1_col0" class="data row1 col0" >-2.500000</td>
#       <td id="T_2aa6e_row1_col1" class="data row1 col1" >5.900000</td>
#     </tr>
#     <tr>
#       <th id="T_2aa6e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2aa6e_row2_col0" class="data row2 col0" >3.530000</td>
#       <td id="T_2aa6e_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# hover yellow along the table
df = pd.DataFrame( np.random.randn(5,3)) # matrix de 5 filas y 3 columnas

df.style.set_table_styles(
    [{'selector': 'r.hover',
      'props': [('color', 'yellow')]}]
)
# Out:
# <style type="text/css">
# #T_77ce3 r.hover {
#   color: yellow;
# }
# </style>
# <table id="T_77ce3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77ce3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_77ce3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_77ce3_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77ce3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77ce3_row0_col0" class="data row0 col0" >-0.350695</td>
#       <td id="T_77ce3_row0_col1" class="data row0 col1" >-2.537429</td>
#       <td id="T_77ce3_row0_col2" class="data row0 col2" >-0.203023</td>
#     </tr>
#     <tr>
#       <th id="T_77ce3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77ce3_row1_col0" class="data row1 col0" >0.242781</td>
#       <td id="T_77ce3_row1_col1" class="data row1 col1" >-1.315452</td>
#       <td id="T_77ce3_row1_col2" class="data row1 col2" >-0.788277</td>
#     </tr>
#     <tr>
#       <th id="T_77ce3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77ce3_row2_col0" class="data row2 col0" >-1.338207</td>
#       <td id="T_77ce3_row2_col1" class="data row2 col1" >-0.806728</td>
#       <td id="T_77ce3_row2_col2" class="data row2 col2" >1.222976</td>
#     </tr>
#     <tr>
#       <th id="T_77ce3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77ce3_row3_col0" class="data row3 col0" >-0.110106</td>
#       <td id="T_77ce3_row3_col1" class="data row3 col1" >0.821389</td>
#       <td id="T_77ce3_row3_col2" class="data row3 col2" >-0.566227</td>
#     </tr>
#     <tr>
#       <th id="T_77ce3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77ce3_row4_col0" class="data row4 col0" >0.493085</td>
#       <td id="T_77ce3_row4_col1" class="data row4 col1" >2.746706</td>
#       <td id="T_77ce3_row4_col2" class="data row4 col2" >1.647830</td>
#     </tr>
#   </tbody>
# </table>

# %%
# este es mas complicado
df.style.set_table_styles(
    [{'selector':'th', 
      'props':[('background', 'blue'),
               ('color', 'white'),
               ('font-family', 'verdana')]},
     
     {'selector': 'td',
     'props' : [('font-family', 'verdana')]},

     {'selector': 'tr-nth-of-type(odd)', 
      'props':[('background', 'green')]},
     
     {'selector': 'tr-nth-of-type(even)', 
      'props' :[('background', 'white')]}
    ]
).hide()
# Out:
# <style type="text/css">
# #T_58cc7 th {
#   background: blue;
#   color: white;
#   font-family: verdana;
# }
# #T_58cc7 td {
#   font-family: verdana;
# }
# #T_58cc7 tr-nth-of-type(odd) {
#   background: green;
# }
# #T_58cc7 tr-nth-of-type(even) {
#   background: white;
# }
# </style>
# <table id="T_58cc7" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_58cc7_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_58cc7_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_58cc7_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_58cc7_row0_col0" class="data row0 col0" >-0.350695</td>
#       <td id="T_58cc7_row0_col1" class="data row0 col1" >-2.537429</td>
#       <td id="T_58cc7_row0_col2" class="data row0 col2" >-0.203023</td>
#     </tr>
#     <tr>
#       <td id="T_58cc7_row1_col0" class="data row1 col0" >0.242781</td>
#       <td id="T_58cc7_row1_col1" class="data row1 col1" >-1.315452</td>
#       <td id="T_58cc7_row1_col2" class="data row1 col2" >-0.788277</td>
#     </tr>
#     <tr>
#       <td id="T_58cc7_row2_col0" class="data row2 col0" >-1.338207</td>
#       <td id="T_58cc7_row2_col1" class="data row2 col1" >-0.806728</td>
#       <td id="T_58cc7_row2_col2" class="data row2 col2" >1.222976</td>
#     </tr>
#     <tr>
#       <td id="T_58cc7_row3_col0" class="data row3 col0" >-0.110106</td>
#       <td id="T_58cc7_row3_col1" class="data row3 col1" >0.821389</td>
#       <td id="T_58cc7_row3_col2" class="data row3 col2" >-0.566227</td>
#     </tr>
#     <tr>
#       <td id="T_58cc7_row4_col0" class="data row4 col0" >0.493085</td>
#       <td id="T_58cc7_row4_col1" class="data row4 col1" >2.746706</td>
#       <td id="T_58cc7_row4_col2" class="data row4 col2" >1.647830</td>
#     </tr>
#   </tbody>
# </table>

# %%
# introduzcamos numeros nan
df.iloc[2,2] = np.nan
df.iloc[1,1] = np.nan

df
# Out:
#           0         1         2
# 0 -0.350695 -2.537429 -0.203023
# 1  0.242781       NaN -0.788277
# 2 -1.338207 -0.806728       NaN
# 3 -0.110106  0.821389 -0.566227
# 4  0.493085  2.746706  1.647830

# %%
df.style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8fc54" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_8fc54_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8fc54_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8fc54_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8fc54_row0_col0" class="data row0 col0" >-0.350695</td>
#       <td id="T_8fc54_row0_col1" class="data row0 col1" >-2.537429</td>
#       <td id="T_8fc54_row0_col2" class="data row0 col2" >-0.203023</td>
#     </tr>
#     <tr>
#       <td id="T_8fc54_row1_col0" class="data row1 col0" >0.242781</td>
#       <td id="T_8fc54_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_8fc54_row1_col2" class="data row1 col2" >-0.788277</td>
#     </tr>
#     <tr>
#       <td id="T_8fc54_row2_col0" class="data row2 col0" >-1.338207</td>
#       <td id="T_8fc54_row2_col1" class="data row2 col1" >-0.806728</td>
#       <td id="T_8fc54_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_8fc54_row3_col0" class="data row3 col0" >-0.110106</td>
#       <td id="T_8fc54_row3_col1" class="data row3 col1" >0.821389</td>
#       <td id="T_8fc54_row3_col2" class="data row3 col2" >-0.566227</td>
#     </tr>
#     <tr>
#       <td id="T_8fc54_row4_col0" class="data row4 col0" >0.493085</td>
#       <td id="T_8fc54_row4_col1" class="data row4 col1" >2.746706</td>
#       <td id="T_8fc54_row4_col2" class="data row4 col2" >1.647830</td>
#     </tr>
#   </tbody>
# </table>

# %%
# busquemos los nan
df.style.highlight_null(null_color="green")
# Out:
# <ipython-input-82-877d878ef1ce>:2: FutureWarning: `null_color` is deprecated: use `color` instead
#   df.style.highlight_null(null_color="green")
# <style type="text/css">
# #T_57d92_row1_col1, #T_57d92_row2_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_57d92" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57d92_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_57d92_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_57d92_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57d92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57d92_row0_col0" class="data row0 col0" >-0.350695</td>
#       <td id="T_57d92_row0_col1" class="data row0 col1" >-2.537429</td>
#       <td id="T_57d92_row0_col2" class="data row0 col2" >-0.203023</td>
#     </tr>
#     <tr>
#       <th id="T_57d92_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57d92_row1_col0" class="data row1 col0" >0.242781</td>
#       <td id="T_57d92_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_57d92_row1_col2" class="data row1 col2" >-0.788277</td>
#     </tr>
#     <tr>
#       <th id="T_57d92_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57d92_row2_col0" class="data row2 col0" >-1.338207</td>
#       <td id="T_57d92_row2_col1" class="data row2 col1" >-0.806728</td>
#       <td id="T_57d92_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_57d92_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57d92_row3_col0" class="data row3 col0" >-0.110106</td>
#       <td id="T_57d92_row3_col1" class="data row3 col1" >0.821389</td>
#       <td id="T_57d92_row3_col2" class="data row3 col2" >-0.566227</td>
#     </tr>
#     <tr>
#       <th id="T_57d92_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57d92_row4_col0" class="data row4 col0" >0.493085</td>
#       <td id="T_57d92_row4_col1" class="data row4 col1" >2.746706</td>
#       <td id="T_57d92_row4_col2" class="data row4 col2" >1.647830</td>
#     </tr>
#   </tbody>
# </table>

# %%
s = df.style  # un alias
s.applymap( lambda x: 'color:green' if pd.isnull(x) else '')
# Out:
# <style type="text/css">
# #T_1113e_row1_col1, #T_1113e_row2_col2 {
#   color: green;
# }
# </style>
# <table id="T_1113e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1113e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1113e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1113e_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1113e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1113e_row0_col0" class="data row0 col0" >-0.350695</td>
#       <td id="T_1113e_row0_col1" class="data row0 col1" >-2.537429</td>
#       <td id="T_1113e_row0_col2" class="data row0 col2" >-0.203023</td>
#     </tr>
#     <tr>
#       <th id="T_1113e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1113e_row1_col0" class="data row1 col0" >0.242781</td>
#       <td id="T_1113e_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_1113e_row1_col2" class="data row1 col2" >-0.788277</td>
#     </tr>
#     <tr>
#       <th id="T_1113e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1113e_row2_col0" class="data row2 col0" >-1.338207</td>
#       <td id="T_1113e_row2_col1" class="data row2 col1" >-0.806728</td>
#       <td id="T_1113e_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1113e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1113e_row3_col0" class="data row3 col0" >-0.110106</td>
#       <td id="T_1113e_row3_col1" class="data row3 col1" >0.821389</td>
#       <td id="T_1113e_row3_col2" class="data row3 col2" >-0.566227</td>
#     </tr>
#     <tr>
#       <th id="T_1113e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1113e_row4_col0" class="data row4 col0" >0.493085</td>
#       <td id="T_1113e_row4_col1" class="data row4 col1" >2.746706</td>
#       <td id="T_1113e_row4_col2" class="data row4 col2" >1.647830</td>
#     </tr>
#   </tbody>
# </table>

# %%
# hallar maximos y minimos

def highlight_max(s):
    is_max = s == s.max()
    return['background-color: yellow' if v else '' for v in is_max]  

with pd.option_context('display.precision', 2):
    html = (df.style.applymap(color_negative_red).apply(highlight_max))

html
# Out:
# <style type="text/css">
# #T_198e0_row0_col0, #T_198e0_row0_col1, #T_198e0_row0_col2, #T_198e0_row1_col2, #T_198e0_row2_col0, #T_198e0_row2_col1, #T_198e0_row3_col0, #T_198e0_row3_col2 {
#   color: red;
# }
# #T_198e0_row1_col0, #T_198e0_row1_col1, #T_198e0_row2_col2, #T_198e0_row3_col1 {
#   color: black;
# }
# #T_198e0_row4_col0, #T_198e0_row4_col1, #T_198e0_row4_col2 {
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_198e0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_198e0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_198e0_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_198e0_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_198e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_198e0_row0_col0" class="data row0 col0" >-0.350695</td>
#       <td id="T_198e0_row0_col1" class="data row0 col1" >-2.537429</td>
#       <td id="T_198e0_row0_col2" class="data row0 col2" >-0.203023</td>
#     </tr>
#     <tr>
#       <th id="T_198e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_198e0_row1_col0" class="data row1 col0" >0.242781</td>
#       <td id="T_198e0_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_198e0_row1_col2" class="data row1 col2" >-0.788277</td>
#     </tr>
#     <tr>
#       <th id="T_198e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_198e0_row2_col0" class="data row2 col0" >-1.338207</td>
#       <td id="T_198e0_row2_col1" class="data row2 col1" >-0.806728</td>
#       <td id="T_198e0_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_198e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_198e0_row3_col0" class="data row3 col0" >-0.110106</td>
#       <td id="T_198e0_row3_col1" class="data row3 col1" >0.821389</td>
#       <td id="T_198e0_row3_col2" class="data row3 col2" >-0.566227</td>
#     </tr>
#     <tr>
#       <th id="T_198e0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_198e0_row4_col0" class="data row4 col0" >0.493085</td>
#       <td id="T_198e0_row4_col1" class="data row4 col1" >2.746706</td>
#       <td id="T_198e0_row4_col2" class="data row4 col2" >1.647830</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Math on dataframes

# %%
df['col_total'] = df.apply( lambda x: x.sum(), axis=1)  # suma por filas
df.loc['row_total'] = df.apply(lambda x: x.sum())  # por defecto suma por columas
df
# Out:
#                   0         1         2  col_total
# 0         -0.350695 -2.537429 -0.203023  -3.091147
# 1          0.242781       NaN -0.788277  -0.545497
# 2         -1.338207 -0.806728       NaN  -2.144935
# 3         -0.110106  0.821389 -0.566227   0.145055
# 4          0.493085  2.746706  1.647830   4.887620
# row_total -1.063142  0.223937  0.090302  -0.748903

# %%
np.abs(df)
# Out:
#                   0         1         2  col_total
# 0          0.350695  2.537429  0.203023   3.091147
# 1          0.242781       NaN  0.788277   0.545497
# 2          1.338207  0.806728       NaN   2.144935
# 3          0.110106  0.821389  0.566227   0.145055
# 4          0.493085  2.746706  1.647830   4.887620
# row_total  1.063142  0.223937  0.090302   0.748903

# %%
np.exp(df)
# Out:
#                   0          1         2   col_total
# 0          0.704198   0.079069  0.816260    0.045450
# 1          1.274789        NaN  0.454627    0.579554
# 2          0.262316   0.446316       NaN    0.117076
# 3          0.895739   2.273655  0.567663    1.156104
# 4          1.637359  15.591184  5.195691  132.637535
# row_total  0.345369   1.250992  1.094505    0.472885

# %%
np.sqrt(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)
#                   0         1         2  col_total
# 0               NaN       NaN       NaN        NaN
# 1          0.492728       NaN       NaN        NaN
# 2               NaN       NaN       NaN        NaN
# 3               NaN  0.906305       NaN   0.380861
# 4          0.702200  1.657319  1.283678   2.210796
# row_total       NaN  0.473220  0.300503        NaN

# %%
np.sqrt(df[:1])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)
#     0   1   2  col_total
# 0 NaN NaN NaN        NaN

# %%
df = pd.DataFrame( np.random.randn(5,3)) # matrix de 5 filas y 3 columnas
df
# Out:
#           0         1         2
# 0  1.558234 -1.250265 -1.468101
# 1  0.328279  0.235364  0.419393
# 2  0.573357 -0.447822 -0.522703
# 3  0.492434  0.608561 -1.196233
# 4 -0.101261 -0.333747 -0.103134

# %%
df[:1]  # primera fila
# Out:
#           0         1         2
# 0  1.558234 -1.250265 -1.468101

# %%
np.sqrt(df[:1])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)
#           0   1   2
# 0  1.248292 NaN NaN

# %%
df['col_total'] = df.apply( lambda x: x.sum(), axis=1)  # suma por filas
df.loc['row_total'] = df.apply(lambda x: x.sum())  # por defecto suma por columas
df
# Out:
#                   0         1         2  col_total
# 0          1.558234 -1.250265 -1.468101  -1.160132
# 1          0.328279  0.235364  0.419393   0.983036
# 2          0.573357 -0.447822 -0.522703  -0.397168
# 3          0.492434  0.608561 -1.196233  -0.095238
# 4         -0.101261 -0.333747 -0.103134  -0.538143
# row_total  2.851043 -1.187909 -2.870778  -1.207643

# %%
np.sqrt(np.abs(df['col_total']))  # valor absoluto y raiz cuadrada en col total
# Out:
# 0            1.077094
# 1            0.991482
# 2            0.630212
# 3            0.308606
# 4            0.733582
# row_total    1.098928
# Name: col_total, dtype: float64

# %% [markdown]
# ## Export a excel (CSV: Comma separated values

# %%
from google.colab import files
df.to_csv('output.csv', encoding='utf-8-sig')
files.download('output.csv')

# %%
ls
# Out:
# output.csv  sample_data/
