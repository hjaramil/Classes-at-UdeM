# %% [markdown]
# ## Operadores entree mas de dos objetos numericos

# %%
a=3**3 + 2 # primero potencia despues suma
b=3/2-3  # primero division despues resta
c=3**(3+2) #
d=3/(2-3)
print("a=%f, b=%f, c=%f, d=%0.2f"%(a,b,c,d))
# Out:
# a=29.000000, b=-1.500000, c=243.000000, d=-3.00

# %%
## Operaciones entre cadenas
a="hola  "
b="como estas ?"
c=a+b  # + es concatenacion
print(c)
# Out:
# hola  como estas ?

# %%
d=3*a
print(d)
# Out:
# hola  hola  hola

# %% [markdown]
# # Operadores entre bits
# La representacion binaria de $5$ es $101$, la representacion binaria de $3$ es $011$. La operacion $|$ compabara bit por bit y solo si los dos bit son 0 arroja 0 (or, disjuncion "o"), de otra forma arroja 1.
#
# Es decir:
#
# \begin{equation}
# 101  \\
# \, 011  \\
# ----  \\
# 111
# \end{equation}
# de forma que "$5 | 3 = 7$" (bitwise or).
#
# El "o" exclusivo "^" solo es 0 cuando ambos son iguales y uno cuando son diferentes
#
# \begin{equation}\
# 101  \\
# \, 011  \\
# ----  \\
# 110
# \end{equation}
#
# La conjuncion "&". Solo cuando los dos son verdaero.
#
# \begin{equation}\
# 101  \\
# \, 011  \\
# ----  \\
# 001
# \end{equation}

# %%
5 | 3
# Out:
# 7

# %%
5^3
# Out:
# 6

# %%
5 & 3
# Out:
# 1

# %% [markdown]
# ### Operadores de desplazamiento (shift).
# El operador ">>" desplaza los bits a la derecha. Por ejemplo
# 5>>2, que hace?
#
# $$ 101 >>2 \rightarrow 001$$
#
# El operador "<<" desplaza los bits a la izquierda. Por ejemplo
# 5<< 2 que hace?
#
# $$ 101 <<2 \rightarrow  (10100)_2 = 20$$

# %%
5>>2
# Out:
# 1

# %%
5<<2
# Out:
# 20

# %% [markdown]
# # Operadores relacionales, de inclusion y logicos

# %%
5 == 3 # ¿es 5 igual a 3?
# Out:
# False

# %%
5>3
# Out:
# True

# %%
5 != 3
# Out:
# True

# %% [markdown]
# operadores de inclusion

# %%
L=[1,2,3] # lista, la sista es una secuencia de objetos separados por "," entre  corchetes
1 in L
# Out:
# True

# %%
0 in L
# Out:
# False

# %%
a='hola'
o in a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f44a0be8ec54> in <module>
#       1 a='hola'
# ----> 2 o in a
#
# NameError: name 'o' is not defined

# %%
'o' in a
# Out:
# True

# %%
1 == 2 or "hola" == "hola"  # or logico
# Out:
# True

# %%
1==2 and "hola"=="hola"  # and logico
# Out:
# False

# %% [markdown]
# Unary Operators (Operadores unuarios).
# Trabajan solo en un objeto. Por ejemplo -1 (negacion), +1, "~" complemento binario. Por ejemplo para el numero 1, que en binario es $00000001$ el complemento es $11111110$, esto representa 254, o -2, el mas cercano a 0 es -2
# Dos veces negacion nos debe retornar al operador original. La operacion "negacion" es simplimente "not" como se muestra a continuacion

# %%
a=-1
a=+a
print(a)
# Out:
# -1

# %%
a=-a
print(a)
# Out:
# 1

# %%
a=~a  # es el complemento mas cercano a 0
print("el tipo de a es:", type(a))
print(a)
# Out:
# el tipo de a es: <class 'int'>
# 1

# %% [markdown]
# 00000111 El complemento es
# 11111000

# %%
a=7
print(~a)
# Out:
# -8

# %% [markdown]
# 10000011 el complemento es 01111100

# %%
a=131 # 10000011
print(~a)
# Out:
# -132

# %%
a=0
print(~a)
# Out:
# -1

# %% [markdown]
# La operacion "~" niega todos los bits del numero, lo calcula en decimal y le resta 256

# %%
a=6
print(~~a)  # la prueba podria ser de tarea. Con ejemplos.

b = 3>2
print(b)
# Out:
# 6
# True

# %%
c = not b  # not es la negacion
print(c)
# Out:
# False

# %% [markdown]
# # Operaciones matematicas de las librerias base

# %%
a=-5.25345
print("el valor absoluto de a es", abs(a))
# Out:
# el valor absoluto de a es 5.25345

# %%
b=[1,-2,3,8]
print("maximo de la lista be es", max(b))
print("minimo de la lista be es", min(b))
# Out:
# maximo de la lista be es 8
# minimo de la lista be es -2

# %%
# redondeo
print("redondeo de a con un cifra significativa", round(a,0))
print("redondeo de a con tres cifra significativa", round(a,3))
print("redondeo de a con tres cifra significativa", round(a,10))
# si quiere ceros a la derecha
print("con 20 cifras %.20f"%a)
# Out:
# redondeo de a con un cifra significativa -5.0
# redondeo de a con tres cifra significativa -5.253
# redondeo de a con tres cifra significativa -5.25345
# con ceros a la derecha -5.25344999999999995310

# %%
# Tipos compuestos
a=5.8
round(a)
# Out:
# 6

# %%
a=5.86
round(a,1)
# Out:
# 5.9

# %%
??round

# %%
round(5.5)
# Out:
# 6

# %%
round(5.85,1)
# Out:
# 5.8

# %% [markdown]
# a=5.5

# %% [markdown]
# # Tipos compuestos:
# * listas
# * tuplas
# * conjuntos
# * diccionarios

# %% [markdown]
# ## Listas: separadas por coma y entre corchetes

# %%
L=[22, True, "cadena de caracteres", [1,2]]
# veamos como accesar los elementos de la lista

# %%
L
# Out:
# [22, True, 'cadena de caracteres', [1, 2]]

# %%
L[0]
# Out:
# 22

# %%
L[1]
# Out:
# True

# %%
L[2][2]
# Out:
# 'd'

# %%
L[3]
# Out:
# [1, 2]

# %%
L[3][0]
# Out:
# 1

# %%
type(L)
# Out:
# list

# %%
a=[1.0, 2.0, 3.0]
a.append(4.0)  # agregar al final
print(a)
# Out:
# [1.0, 2.0, 3.0, 4.0]

# %%
# si quiere saber mas operaciones en las listas
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
L.clear()  # la vacia

# %%
L
# Out:
# []

# %%
a.insert(0, 0.45) # insertar al comienzo
a
# Out:
# [0.45, 1.0, 2.0, 3.0, 4.0]

# %%
a.remove(2.0)  # remueve el elemento de valor 2.0 en la lista
a
# Out:
# [0.45, 1.0, 3.0, 4.0]

# %%
# remover partes de la lista
b=[1,3,-1,50, 30]
del b[2:]
b
# Out:
# [1, 3]

# %%
# extender la lista
b.extend([3,2,1])
b
# Out:
# [1, 3, 3, 2, 1]

# %%
# imprimir min/max (ya lo vimos)
# imprimir la suma
print("suma de la lista es", sum(b))
# Out:
# suma de la lista es 10

# %%
c=[1, "hola"]
sum(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-03fee789ba7e> in <module>
#       1 c=[1, "hola"]
# ----> 2 sum(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
c=["hola", "como estas"]
sum(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-faa34b65bb7d> in <module>
#       1 c=["hola", "como estas"]
# ----> 2 sum(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
"hola" + "como estas"
# Out:
# 'holacomo estas'

# %%
# ?sum

# %%
# tamano de la lista
len(a)
# Out:
# 4

# %%
# sorting
L = [1, -5, 7, 6]
M = sorted(L)  # sorted

# %%
# accesar elementos de atras hacia adelante
L[-1]
# Out:
# 6

# %%
L
# Out:
# [1, -5, 7, 6]

# %%
L[-2]
# Out:
# 7

# %%
L[-3]
# Out:
# -5

# %%
M
# Out:
# [-5, 1, 6, 7]

# %%
M[-1]
# Out:
# 7

# %%
S = L.reverse()
print(L)
print(S)
# Out:
# [6, 7, -5, 1]
# None

# %%
L
# Out:
# [6, 7, -5, 1]

# %%
L.reverse()

# %%
L
# Out:
# [1, -5, 7, 6]

# %%
??L.reverse

# %%
# listas de cadenas de caracteres
l = ["juan", "luis", "gustavo"]
l[0]
# Out:
# 'juan'

# %%
l[0][2]
# Out:
# 'a'

# %%
# listas de listas
edades=[30,20,50]
[l, edades]
# Out:
# [['juan', 'luis', 'gustavo'], [30, 20, 50]]

# %%
# multiplicacion de una lista por un escalar
L=['a', 'b']
3*L
# Out:
# ['a', 'b', 'a', 'b', 'a', 'b']

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
# la lista vacia
A=[]
len(A)
# Out:
# 0

# %% [markdown]
# ## Tuplas:
# Estas estan tambien separadas por comas y entre parentesis. Pero parentesis no son obligatorios

# %%
t=1
print("el tipo de t es", type(t))
t=1,
print("el tipo de t es ahora",  type(t))
# Out:
# el tipo de t es <class 'int'>
# el tipo de t es ahora <class 'tuple'>

# %%
# la tupla no se puede modificar. Es inmutable, la lista si.
t = 1,2,3  # parentesis no es obligatorio
t.append(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-f49a8fda63c3> in <module>
#       1 # la tupla no se puede modificar. Es inmutable, la lista si.
#       2 t = 1,2,3  # parentesis no es obligatorio
# ----> 3 t.append(1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
len(t)
# Out:
# 3

# %%
t
# Out:
# (1, 2, 3)

# %%
# mas ejemplos
T = 'e','i', 'a', 'u', 'o'
print("Tupla", T, "del tipo ", type(T))
TS = sorted(T)
print("se convierte en ", TS, "del tipo", type(TS))
# Out:
# Tupla ('e', 'i', 'a', 'u', 'o') del tipo  <class 'tuple'>
# se convierte en  ['a', 'e', 'i', 'o', 'u'] del tipo <class 'list'>

# %%
# multiplicacion por escalar
2*TS
# Out:
# ['a', 'e', 'i', 'o', 'u', 'a', 'e', 'i', 'o', 'u']

# %%
2*T  # se comporta como una lista
# Out:
# ('e', 'i', 'a', 'u', 'o', 'e', 'i', 'a', 'u', 'o')

# %%
S = ()
len(S)
# Out:
# 0

# %%
L=[1,2,3]
L.pop()
# Out:
# 3

# %%
L
# Out:
# [1, 2]

# %%
# las tuplas se pueden desempacar
registro = "Tomas", "Estrada", (10, 5, 2001)
nombre, apellido, nacimiento = registro
print("mi nombre es", nombre)
print("mi apellido es", apellido)
print("mi fecha de nacimiento es", nacimiento)
# Out:
# mi nombre es Tomas
# mi apellido es Estrada
# mi fecha de nacimiento es (10, 5, 2001)

# %%
import numpy as np
a = np.array([1,3,5])
print(a)
# Out:
# [1 3 5]

# %%
b = np.array([[21,3], [-1,6]])
print(b)
# Out:
# [[21  3]
#  [-1  6]]

# %%
dir(b)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
# ...

# %%
L=[5,2]
max(L)
# Out:
# 5

# %%
L.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-e7963de186d7> in <module>
# ----> 1 L.mean()
#
# AttributeError: 'list' object has no attribute 'mean'

# %% [markdown]
# ## Conjuntos
# separados por comas y entre llaves

# %%
L=[10,1,3,4,4,1,"a", "hola"]
print("L=", L, "es de tipo", type(L))
setL = set(L)  # casting de lista a conjunto
print("el conjunto setL", setL, "es de tipo", type(setL))
# Out:
# L= [10, 1, 3, 4, 4, 1, 'a', 'hola'] es de tipo <class 'list'>
# el conjunto setL {1, 3, 4, 'a', 'hola', 10} es de tipo <class 'set'>

# %%
M = {10, 1, 3, 4, 4, 1, 'a', 'hola'}
print(M)
# Out:
# {1, 3, 4, 'a', 'hola', 10}

# %%
### Operaciones entre conjuntos
A = set(['a', 'b', 'c'])
B = {'b', 'c', 'd'}

print("A tiene", len(A), "elementos")
# Out:
# A tiene 3 elementos

# %%
print("Esta 'a' en A?", 'a' in A)  # pertenencia
# Out:
# Esta 'a' en A? True

# %%
print("A unido B", A.union(B))
# Out:
# A unido B {'b', 'a', 'd', 'c'}

# %%
print("A intersectado B", A.intersection(B))
# Out:
# A intersectado B {'b', 'c'}

# %%
print("A \ B", A.difference(B))
# Out:
# A \ B {'a'}

# %%
print("A superconjunto de B", A.issuperset(B))
# Out:
# A superconjunto de B False

# %%
print("A subconjunto de B", A.issubset(B))
# Out:
# A subconjunto de B False

# %%
print("A diferencia simetrica con B", A.symmetric_difference(B))
# Out:
# A diferencia simetrica con B {'a', 'd'}
