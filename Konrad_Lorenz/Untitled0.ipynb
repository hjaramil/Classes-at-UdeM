# %% [markdown]
# # Ejercicio de convertir los digitos 0,1,2 , 9 manuscritos a digitales.
# Base de datos MNIST

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
from matplotlib import pyplot
from scipy import optimize
from scipy.io import loadmat

# %%
# %matplotlib inline
cd gdrive/MyDrive/Colab\ Notebooks/Konrad_Lorenz/Exercise4
data = loadmat(os.path.join('Data', 'ex4data1.mat'))
# Out:
#   File "<ipython-input-5-fa3780e3bad7>", line 2
#     cd gdrive/MyDrive/Colab\ Notebooks/Konrad_Lorenz/Exercise4
#             ^
# SyntaxError: invalid syntax
