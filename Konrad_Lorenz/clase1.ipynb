# %% [markdown]
# # OCR: Optical Character Regonizion: Reconocimiento de caracteres opticos.
#
#
# ## Historia:
# 1. En 1914 Emanuel Goldberg desarrolló una maquina que leia caracteres y los convertia a tipo telegrafico. Edumnd Fournier invento el Optophone.
# 2. En la tercera decada del siglo XX Emanuel Goldberg, invento la "Maquina estadistica" que escanea un documento y produce tonos diversos.
# 3. Hoy, el uso de OCR se extiende a telefonos inteligentes: photomat, gafas inteligentes, carros autonomos, etc.
#
# ## Aplicaciones:
# Ya mencionamos shapecatcher.com, ya mencionamos photomath y
# 1. Digitalizacion de documentos. Imaginense cuantos juzagados en el mundo estan llenos de archivo con miles de paginas de documentos.  La digitalizacion de documentos es de gran importancia. Hay una aplicacion que se llama  [Tesseract](https://github.com/tesseract-ocr/tesseract)
#
# 2. OCR es parte de una tecnologia conocidas como Object Detection, y este a su vez de Computer Vision.
#
# 3. Extraccion de datos importantes. Placas de carros.
# En aeropuertos, leer pasaportes.

# %% [markdown]
# ## Metodologia de OCR.

# %% [markdown]
# ![Selection_005.png](data:image/png;base64,...)

# %% [markdown]
# 1. Deteccion de texto
# 2. Segmentacion de texto
# 3. Clasificacion de caracteres
# 4. El procesamiento
#
# ![Selection_006.png](data:image/png;base64,...)

# %% [markdown]
# 1. Deteccion de texto: Se explora la imagen y de identifica las areas donde hay y no hay texto. Para esto se utilizan "bounding boxes". Cajas de delimitacion.

# %% [markdown]
# ![Selection_007.png](data:image/png;base64,...)

# %% [markdown]
# Esta es la forma en que detecta el texto. Pero que recuerde los
# otros pasos. Segmentacion y la clasificacion. Tomemos una figura
# general de de los tres pasos.
#
# ![Selection_008.png](data:image/png;base64,...)

# %% [markdown]
# Otra figura de distincion entre texto y no texto (pregunta de Andres)
#
# ![Selection_009.png](data:image/png;base64,...)
