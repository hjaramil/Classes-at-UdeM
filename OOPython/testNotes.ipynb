# %%
pwd
# Out:
# '/content'

# %%
import os
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-837f90cc644e> in <module>
# ----> 1 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     103       force_remount=force_remount,
#     104       timeout_ms=timeout_ms,
# --> 105       ephemeral=True)
#     106
#     107
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     118   if ephemeral:
#     119     _message.blocking_request(
# --> 120         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     121
#     122   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
# ...

# %%
pwd
cd /content/sample_data/anscombe.json
# Out:
# '/content'

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
#  20160619_141407.jpg
#  20160619_145344.jpg
# '2021 (1).gsheet'
# '2021 (2).gsheet'
# '2021 (3).gsheet'
# '2021 (4).gsheet'
#  2021.gsheet
#  56a.wxm
# '5a26731139f97 (1).pdf'
#  5a34003cf3e08.pdf
# 'Acta divorcio Herman IMG.pdf'
#  ambient_rec_20160617_173000.amr
#  analisis_numerico.pdf
#  animline-seaborn.gif
# 'ARBOL GENEALOGICO COMPLETO JARAMILLO BOTERO ESPAÑA-ITALIA.pdf'
# 'Ascendencia de papa pacho Francisco Emilio Jaramillo Uribe.pdf'
#  bisect.pdf
#  carpeta18.doc
#  Cartas/
#  class13.ipynb
#  Cloud/
# 'Colab Notebooks'/
# 'Copy of Copy of Email Permutator (1).gform'
# 'Copy of Copy of Email Permutator.gform'
# 'Copy of Copy of Email Permutator.gsheet'
# 'Copy of Email Permutator (1).gform'
# 'Copy of Email Permutator (1).gsheet'
# 'Copy of Email Permutator (2).gform'
# 'Copy of Email Permutator (3).gform'
# 'Copy of Email Permutator.gform'
# 'Copy of Email Permutator.gsheet'
# 'Copy of herman_seriatim2014.xlsx'
#  cover_letter.pdf
#  C++.tgz
# 'cwp_su_all_44R11 (1).tgz'
# ...

# %%
cd Colab\ Notebooks
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# 'Copy of exercise4.ipynb'    OOpython2/
# 'Copy of Tarea1 MN2.ipynb'   Python_Course/
#  datos.csv                   Quetame_EW_0.txt
# 'Deep Learning'/             SpectrosRespuesta.ipynb
#  Konrad_Lorenz/              Tarea8.ipynb
# 'Machine Learning'/          TensorFlow/
# 'Machine Learning 2022-2'/   TimeSeries/
# 'Machine Learning Juan'/     Untitled0.ipynb
#  OOPython/

# %%
cd OOPython
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/OOPython

# %%
ls
# Out:
# clas13.ipynb   class11.ipynb  class3/  class7/                 __pycache__/
# clase14.ipynb  class12.ipynb  class4/  class8/                 testLocals.py
# class1/        class15.ipynb  class5/  prueba.ipynb            testNotes.ipynb
# class10/       class2/        class6/  pruebaSystemaOperativo

# %%
ls
# Out:
# clas13.ipynb   class11.ipynb  class3/  class7/       pruebaSystemaOperativo
# clase14.ipynb  class12.ipynb  class4/  class8/       __pycache__/
# class1/        class15.ipynb  class5/  cuaderno.py   testLocals.py
# class10/       class2/        class6/  prueba.ipynb  testNotes.ipynb

# %%
from cuaderno import Nota, Cuaderno
n=Cuaderno()
n.notaNueva("Hola mundo")
n.notaNueva("Hola otra vez")
n.notas
# Out:
# [<cuaderno.Nota at 0x7fa49fbd5790>, <cuaderno.Nota at 0x7fa49fbd5110>]

# %%
n.notas[0].id
# Out:
# 0

# %%
n.notas[1].id
# Out:
# 1

# %%
n.notas[0].memo
# Out:
# 'Hola mundo'

# %%
n.notas[1].memo
# Out:
# 'Hola otra vez'

# %%
n.busque("Hola")
# Out:
# [<cuaderno.Nota at 0x7fa49fbd5790>, <cuaderno.Nota at 0x7fa49fbd5110>]

# %%
n.modifiqueMemo(1, "hi world")
n.notas[1].memo
# Out:
# 'hi world'

# %%
n.notaNueva("con etiqueta", "Pedro")
n.notas

# %%
vars(n.notas[0])
# Out:
# {'memo': 'Hola mundo',
#  'etiqueta': '',
#  'fechaDeCreado': datetime.date(2022, 9, 12),
#  'id': 0}

# %%
n.notas[2].etiqueta
# Out:
# 'Pedro'

# %%
vars(n.notas[2])
# Out:
# {'memo': 'con etiqueta',
#  'etiqueta': 'Pedro',
#  'fechaDeCreado': datetime.date(2022, 9, 12),
#  'id': 2}

# %%
n.encuentreNota(3)
# Out:
# no se encontro la nota 3

# %%
n2 = n.encuentreNota(2)
vars(n2)
# Out:
# {'memo': 'con etiqueta',
#  'etiqueta': 'Pedro',
#  'fechaDeCreado': datetime.date(2022, 9, 12),
#  'id': 2}

# %%
n.modifiqueEtiqueta(2, "Juan")
n.notas[2].etiqueta
# Out:
# 'Juan'

# %%
n.notas

# %%
for nota in n.notas:
    print(vars(nota))
# Out:
# {'memo': 'Hola mundo', 'etiqueta': '', 'fechaDeCreado': datetime.date(2022, 9, 12), 'id': 0}
# {'memo': 'hi world', 'etiqueta': '', 'fechaDeCreado': datetime.date(2022, 9, 12), 'id': 1}
# {'memo': 'con etiqueta', 'etiqueta': 'Juan', 'fechaDeCreado': datetime.date(2022, 9, 12), 'id': 2}

# %%
n.imprimaNotas()
# Out:
# {'memo': 'Hola mundo', 'etiqueta': '', 'fechaDeCreado': datetime.date(2022, 9, 12), 'id': 0}
# {'memo': 'hi world', 'etiqueta': '', 'fechaDeCreado': datetime.date(2022, 9, 12), 'id': 1}
# {'memo': 'con etiqueta', 'etiqueta': 'Juan', 'fechaDeCreado': datetime.date(2022, 9, 12), 'id': 2}
