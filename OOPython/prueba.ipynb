# %%
pwd  # path word
# Out:
# '/content'

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
# !ls
# Out:
# MyDrive

# %%
cd MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
cd Colab\ Notebooks
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# 'Copy of exercise4.ipynb'   'Machine Learning Juan'/   Tarea8.ipynb
#  datos.csv                   OOPython/                 TensorFlow/
# 'Deep Learning'/             OOpython2/                TimeSeries/
#  Konrad_Lorenz/              Python_Course/            Untitled0.ipynb
# 'Machine Learning'/          Quetame_EW_0.txt
# 'Machine Learning 2022-2'/   SpectrosRespuesta.ipynb

# %%
cd OOPython
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/OOPython

# %%
ls
# Out:
#  class1/        'class12 (1).ipynb'   class3/   class6/   prueba.ipynb
#  class10/        class12.ipynb        class4/   class7/   Untitled
#  class11.ipynb   class2/              class5/   class8/

# %%
import sys
sys.path.append("/conent/gdrive/MyDrive/Colab Notebooks/OOPython")

# %%
from testLocals import TestLocals

# %%
myTest = TestLocals()
vars(myTest)
# Out:
# {'var1': 'ojo'}
