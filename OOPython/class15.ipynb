# %% [markdown]
# ### Discusion en la tarea. Herencia

# %% [markdown]
# Las variables de instancia son todas aqueyas declaradas en ```__ini__()```.

# %% [markdown]
# Proyecto 1:

# %%
pwd
# Out:
# '/content'

# %%
# !mkdir ComputacionII
# !ls
# Out:
# mkdir: cannot create directory ‘ComputacionII’: File exists
# ComputacionII  gdrive  sample_data

# %%
cd ComputacionII/
# Out:
# /content/ComputacionII

# %%
print(sys.path)
sys.path.append("/content/ComputacionII")
print(sys.path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-16cc88e7f08a> in <module>
# ----> 1 print(sys.path)
#       2 sys.path.append("/content/ComputacionII")
#       3 print(sys.path)
#
# NameError: name 'sys' is not defined

# %%
ls
# Out:
# __pycache__/

# %%
import cuaderno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-1d6ff873b75b> in <module>
# ----> 1 import cuaderno
#
# ModuleNotFoundError: No module named 'cuaderno'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
dir(cuaderno)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4f61e5344e40> in <module>
# ----> 1 dir(cuaderno)
#
# NameError: name 'cuaderno' is not defined

# %%
c=cuaderno.Cuaderno("hola")
vars(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0acec69f28a3> in <module>
# ----> 1 c=cuaderno.Cuaderno("hola")
#       2 vars(c)
#
# NameError: name 'cuaderno' is not defined

# %%
c.imprimaNota()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a8b9cc154387> in <module>
# ----> 1 c.imprimaNota()
#
# NameError: name 'c' is not defined

# %% [markdown]
# Repetimos el procedimiento desde google drive

# %%
import os

# %%
ls
# Out:
# __pycache__/

# %%
cd ..
# Out:
# /content

# %%
ls
# Out:
# ComputacionII/  gdrive/  sample_data/

# %%
import cuaderno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-1d6ff873b75b> in <module>
# ----> 1 import cuaderno
#
# ModuleNotFoundError: No module named 'cuaderno'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-837f90cc644e> in <module>
# ----> 1 drive.mount('/content/gdrive')
#
# NameError: name 'drive' is not defined

# %%
ls

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# !ls
# !cd ColabNotebooks/
# Out:
#  20160619_141407.jpg
#  20160619_145344.jpg
# '2021 (1).gsheet'
# '2021 (2).gsheet'
# '2021 (3).gsheet'
# '2021 (4).gsheet'
#  2021.gsheet
#  56a.wxm
# '5a26731139f97 (1).pdf'
#  5a34003cf3e08.pdf
# 'Acta divorcio Herman IMG.pdf'
#  ambient_rec_20160617_173000.amr
#  analisis_numerico.pdf
#  animline-seaborn.gif
# 'ARBOL GENEALOGICO COMPLETO JARAMILLO BOTERO ESPAÑA-ITALIA.pdf'
# 'Ascendencia de papa pacho Francisco Emilio Jaramillo Uribe.pdf'
#  bisect.pdf
#  carpeta18.doc
#  Cartas
#  class13.ipynb
#  Cloud
#  ColabNotebooks
# 'Copy of Copy of Email Permutator (1).gform'
# 'Copy of Copy of Email Permutator.gform'
# 'Copy of Copy of Email Permutator.gsheet'
# 'Copy of Email Permutator (1).gform'
# 'Copy of Email Permutator (1).gsheet'
# 'Copy of Email Permutator (2).gform'
# 'Copy of Email Permutator (3).gform'
# 'Copy of Email Permutator.gform'
# 'Copy of Email Permutator.gsheet'
# 'Copy of herman_seriatim2014.xlsx'
#  cover_letter.pdf
#  C++.tgz
# 'cwp_su_all_44R11 (1).tgz'
# ...

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
#  20160619_141407.jpg
#  20160619_145344.jpg
# '2021 (1).gsheet'
# '2021 (2).gsheet'
# '2021 (3).gsheet'
# '2021 (4).gsheet'
#  2021.gsheet
#  56a.wxm
# '5a26731139f97 (1).pdf'
#  5a34003cf3e08.pdf
# 'Acta divorcio Herman IMG.pdf'
#  ambient_rec_20160617_173000.amr
#  analisis_numerico.pdf
#  animline-seaborn.gif
# 'ARBOL GENEALOGICO COMPLETO JARAMILLO BOTERO ESPAÑA-ITALIA.pdf'
# 'Ascendencia de papa pacho Francisco Emilio Jaramillo Uribe.pdf'
#  bisect.pdf
#  carpeta18.doc
#  Cartas/
#  class13.ipynb
#  Cloud/
#  ColabNotebooks/
# 'Copy of Copy of Email Permutator (1).gform'
# 'Copy of Copy of Email Permutator.gform'
# 'Copy of Copy of Email Permutator.gsheet'
# 'Copy of Email Permutator (1).gform'
# 'Copy of Email Permutator (1).gsheet'
# 'Copy of Email Permutator (2).gform'
# 'Copy of Email Permutator (3).gform'
# 'Copy of Email Permutator.gform'
# 'Copy of Email Permutator.gsheet'
# 'Copy of herman_seriatim2014.xlsx'
#  cover_letter.pdf
#  C++.tgz
# 'cwp_su_all_44R11 (1).tgz'
# ...

# %%
cd ColabNotebooks/
# Out:
# /content/gdrive/MyDrive/ColabNotebooks

# %%
ls
# Out:
# 'Copy of exercise4.ipynb'    OOpython2/
# 'Copy of Tarea1 MN2.ipynb'   Python_Course/
#  datos.csv                   Quetame_EW_0.txt
# 'Deep Learning'/             SpectrosRespuesta.ipynb
#  Konrad_Lorenz/              Tarea8.ipynb
# 'Machine Learning'/          TensorFlow/
# 'Machine Learning 2022-2'/   TimeSeries/
# 'Machine Learning Juan'/     Untitled0.ipynb
#  OOPython/

# %%
cd OOPython/
# Out:
# /content/gdrive/MyDrive/ColabNotebooks/OOPython

# %%
ls
# Out:
# clas13.ipynb   class11.ipynb  class3/  class7/       pruebaSystemaOperativo
# clase14.ipynb  class12.ipynb  class4/  class8/       __pycache__/
# class1/        class15.ipynb  class5/  cuaderno.py   testLocals.py
# class10/       class2/        class6/  prueba.ipynb  testNotes.ipynb

# %%
cp /content/gdrive/MyDrive/ColabNotebooks/OOPython/cuaderno.py .
# Out:
# cp: '/content/gdrive/MyDrive/ColabNotebooks/OOPython/cuaderno.py' and './cuaderno.py' are the same file

# %%
ls
# Out:
# clas13.ipynb   class11.ipynb  class3/  class7/       pruebaSystemaOperativo
# clase14.ipynb  class12.ipynb  class4/  class8/       __pycache__/
# class1/        class15.ipynb  class5/  cuaderno.py   testLocals.py
# class10/       class2/        class6/  prueba.ipynb  testNotes.ipynb

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/ColabNotebooks/OOPython'

# %%
ls cua*
# Out:
# cuaderno.py

# %%
dir(cuaderno)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-4f61e5344e40> in <module>
# ----> 1 dir(cuaderno)
#
# NameError: name 'cuaderno' is not defined

# %%
ls
# Out:
# clas13.ipynb   class11.ipynb  class3/  class7/       pruebaSystemaOperativo
# clase14.ipynb  class12.ipynb  class4/  class8/       __pycache__/
# class1/        class15.ipynb  class5/  cuaderno.py   testLocals.py
# class10/       class2/        class6/  prueba.ipynb  testNotes.ipynb

# %%
more cuaderno.py

# %%
import cuaderno

# %%
from cuaderno import *

# %%
n=Cuaderno()

# %%
more cuaderno.py

# %%
import os
ls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-0c3c1136f161> in <module>
#       1 import os
# ----> 2 ls
#
# NameError: name 'ls' is not defined

# %%
dir(cuaderno)
# Out:
# ['Cuaderno',
#  'Nota',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'datetime',
#  'ultimoId']

# %%
dir(cuaderno.Cuaderno)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'busque',
#  'encuentreNota',
#  'imprimaNotas',
#  'modifiqueEtiqueta',
#  'modifiqueMemo',
#  'notaNueva']

# %%
del Cuaderno

# %%
import cuaderno
from cuaderno import Cuaderno

# %%
n = Cuaderno()

# %%
n.notaNueva("Hola mundo")
n.notaNueva("Hola otra vez")
n.notas

# %%
n.notas[0].id
# Out:
# 0

# %%
n.notas[1].memo
# Out:
# 'Hola mundo'

# %%
n.busque["Hola"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-da0345f5f690> in <module>
# ----> 1 n.busque["Hola"]
#
# TypeError: 'method' object is not subscriptable
