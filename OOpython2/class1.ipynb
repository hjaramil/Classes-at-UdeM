# %% [markdown]
# # Object Oriented with Python
#
# ## Introduccion
# Lenguajes de programacion:
#
# Podemos pensar en los lenguajes de programacion desde varios puntos de vista
#
# ### Taxonomia de los lenguajes de programacion.
#
# 1.  Alfabetico (el menos interesante
#
#     [Alfabetico](https://en.wikipedia.org/wiki/List_of_programming_languages)
#
# 2. Cronologico.
# [Timeline](https://en.wikipedia.org/wiki/Timeline_of_programming_languages)
#
# 3. Tipo:
# [tipo](https://en.wikipedia.org/wiki/List_of_programming_languages_by_type)
#
# 4. Modelo de ejeucion  :
# [Modelo de ejeucion](https://en.wikipedia.org/wiki/Execution_model).
#     Dos pilares importantes. Los programs se pueden compilar
#     o son interpretables (compilor vs interpreter).
#     Compilar: C, C++, Java, Fortran (Formula Translation) , etc
#     Interpreter: Python, Beginners All purpose Symbolic Instruction Code (BASIC)
#
#     Ventajas de compilados: Son mas rapidos.
#     Desventajas de Compilados: no son interactivos.
#
# ### Por que Python?
# Hay muchos lenguages con orientacion a objeto: C++, Java, JavasScript,  Simula (origen), etc.
#
# 1. Es el mas popular (con JavaScript)
# 2. Python tiene una sintaxis mas amigable.
# 3. Es simple. Es typeless: No necesita tipos.
# 4. Es interactivo. Las plataformas: Jupyter (Jupyter-lab) y Google colab son muy utiles. Es mas, Google Colab (mi tablero de clases) solo trabaja con Python.
#
# Jupyter: Julia, Python  y R
#
# Prerequisitos: curso basico en Python.

# %% [markdown]
# ## Paradigmas de Programacion
# Por que Object Oriented (programacion orientada a objetos)
#
# [Que es un paradigma](https://en.wikipedia.org/wiki/Programming_paradigm)
#
# ![Selection_009.png](data:image/png;base64,...)

# %% [markdown]
# Un paradigma es un metodo o un estilo de escribir codigo.

# %% [markdown]
# Hay dos escquemas importantes en los paradigms:
#
# 1. Programacion imperativa (imperative programming)
#
#     - Programacion libre
#     - Programacion estructurada
#     - Programacion en procedimientos (procedural programming)
#     - Object oriented (orientada a objetos)
# 2. Programacion declarativa.
#
#     - programacion logica (logical programming)
#     - funcional programming

# %% [markdown]
# ### Paradigma Programacion imperativa.
# Ejemplos de lenguajes que la usan: Fortran, C, C++, Java, Python, etc.
#
# Que es el paradigma imperativo. El control es de paso-a-paso. Extricto. Top-Down. Como lee la pagina de un libro.
#
# ####Programacion libre.
#
# Para entender el paradigma de programacion estructurada debemos entener lo que paso antes "programcion libre". Programacion gon "goto".
# goto 10 : quiere decir, "VAYASE a la etiqueta 10.
#
# Se usaba mucho en Fortrana y BASIC.
#
# Un ejemplo en BASIC. Halle los cuadrados de los
# numeros del 1 al 100 en BASIC
#
# ```
# 1  i=0;
# 2  i=i+1;
# 3  PRINT i; "squared="; i*i;
# 4  IF i >= 100 THEN GOTO 6;
# 5  GOTO 2
# 6  PRINT "programa finalizado"
# 7  END
# ```

# %%
# como seria este codigo en Python.
for i in range(1,101):
    print("i=%d, squared=%d"%(i, i*i))
# Out:
# i=1, squared=1
# i=2, squared=4
# i=3, squared=9
# i=4, squared=16
# i=5, squared=25
# i=6, squared=36
# i=7, squared=49
# i=8, squared=64
# i=9, squared=81
# i=10, squared=100
# i=11, squared=121
# i=12, squared=144
# i=13, squared=169
# i=14, squared=196
# i=15, squared=225
# i=16, squared=256
# i=17, squared=289
# i=18, squared=324
# i=19, squared=361
# i=20, squared=400
# i=21, squared=441
# i=22, squared=484
# i=23, squared=529
# i=24, squared=576
# i=25, squared=625
# i=26, squared=676
# i=27, squared=729
# i=28, squared=784
# i=29, squared=841
# i=30, squared=900
# i=31, squared=961
# i=32, squared=1024
# i=33, squared=1089
# i=34, squared=1156
# i=35, squared=1225
# i=36, squared=1296
# i=37, squared=1369
# i=38, squared=1444
# i=39, squared=1521
# i=40, squared=1600
# i=41, squared=1681
# i=42, squared=1764
# i=43, squared=1849
# i=44, squared=1936
# i=45, squared=2025
# i=46, squared=2116
# i=47, squared=2209
# i=48, squared=2304
# i=49, squared=2401
# i=50, squared=2500
# ...

# %% [markdown]
# Los codigos con "muchos" goto se llaman "codigos espageti"
#
# [spaghetti code](https://en.wikipedia.org/wiki/Spaghetti_code)
#
# Otro ejemplo.
#
# ![Selection_010.png](data:image/png;base64,...)

# %% [markdown]
# Dijkstra (holandes) escribio el ariculo "goto considered harmful"
# [Dijksra](https://en.wikipedia.org/wiki/Considered_harmful).
#
# Donald Knut no esta de acuerdo y dici que algunas veces es bueno tenerlo.
#
# Hay blog en
# [StackOverflow](https://stackoverflow.com/questions/3517726/what-is-wrong-with-using-goto)
# tiene un discusion extensa en las ventajas y desventajas de GOTO.
#
# ![Selection_011.png](data:image/png;base64,...)

# %% [markdown]
# La imagen de arriba (tomada de StackOverflow) ilustra una situacion en la cual goto es efectivo.
