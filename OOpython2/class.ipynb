# %% [markdown]
# ## Agregacion (Aggregation)
# Como parte de Asociacion, la vez pasada, hablamos de Composicion (es parte de) hoy hablamos de agregacion. ("tiene un ").

# %%
# repetimos el ejeplo del segumento y lo extendenmos luego a un triangulo.
# esta vez usando agragacion en vez de composicion.

# clase punto
class Point:
    def __init__(self, x, y ):
        self.x = x
        self.y = y
        return 

    def norm(self):
        return ( (self.x)**2 + (self.y)**2)**(0.5)

class Segment:
    def __init__(self, x1, y1, point):
        self.x1 = x1
        self.y1 = y1
        return 

        # chequeo que punto es istancia de Point
        if not isinstance(point, Point):
            rint("la firma (signature) es coordenadas x, y y eun punto p")
        return

    # como punto es una instancia de Punto lo podemos "agregar"

        ## punto nuevo. El segmento lo voy a mover al origen, por que alli le 
        ## calculo la norma y esa la longitud.
        point.x = point.x - self.x1
        point.y = point.y - self.y1
        return

    # calculo de la longitud del segmento usando norma
    def lengthSegment(self):
        return point.norm()


# prueba
point = Point(5,6)
seg = Segment(3,4, point)  # agregacion
print(seg.lengthSegment())
# Out:
# 7.810249675906654

# %%
print(point)

# %%
# prueba
import numpy as np
p1 = np.array([3,4])
p2 = np.array([5,6])
dist = np.linalg.norm(p2-p1)
dist
# Out:
# 2.8284271247461903

# %%
class Point:
    def __init__(self, x, y ):
        self.x = x
        self.y = y
        return 

    def draw():
        pass

    def __str__(self):
        return f"({self.x}, {self.y})"

    # sobrecargar la resta de puntos (la sobrecarga la estudiamos despues)
    def __sub__(self, other):
        x = self.x - other.x
        y = self.y - other.y
        return (x, y)

# %%
point1 = Point(5,6)
point2 = Point(3,0)
point1-point2
# Out:
# (2, 6)

# %%
print(point1)
print(point2)
# Out:
# (5, 6)
# (3, 0)

# %%
from numpy import sqrt
import matplotlib.pyplot as plt
class Segment():

    def __init__(self, p1, p2, color="blue"):
        self.p1 = p1
        self.p2 = p2
        self.color = color
        return

        # chequeo que punto es istancia de Point
        if not isinstance(self.p1, Point):
            print("la firma (signature) es coordenadas x, y y eun punto p")
        return

        if not isinstance(p2, Point):
            print("la firma (signature) es coordenadas x, y y eun punto p")
        return


    def length(self):
        return ( (p2.x - p1.x)**2  + (p2.y - p1.y)**2 )**0.5

p1 = Point(3,4)  # AGREGACION
p2 = Point(2,3)
s1 = Segment(p1, p2, "red")
print(s1.p2)
# Out:
# (2, 3)

# %%
print(s1.color)
# Out:
# red

# %%
s1.length()
# Out:
# 1.4142135623730951

# %%
( (p1.x - p2.x)**2 + (p1.y-p2.y)**2 )**0.5
# Out:
# 1.4142135623730951

# %%
print(p1)
print(p2)
# Out:
# (3, 4)
# (2, 3)

# %%
# construccion del traiangulo:
class Triangle():

    def __init__(self, p1, p2, p3, color="blue"):
        self.p1 = p1
        self.p2 = p2
        self.p3 = p3
        self.color = color

        # construimos los lados del triangulo
        self.side1 = Segment(p1, p2)  # composition
        self.side2 = Segment(p2, p3)
        self.side3 = Segment(p3, p1)

        print("ojo ", self.side2.length())
        return


    def lengthSides(self):
        # Ojoooo esto es un no! no!. De tres lineas repetidas para adelante
        # hacer ciclo (for)
        print(f"lado entre {self.p1} y {self.p2} tiene longitud {self.side1.length()}")
        print(f"lado entre {self.p2} y {self.p3} tiene longitud {self.side2.length()}")
        print(f"lado entre {self.p3} y {self.p1} tiene longitud {self.side3.length()}")
        return

    def perimeter(self):

        # la suma siguiente debe ser un loop.
        return self.side1.length() + self.side2.length() + self.side3.length()

    def findArea(self):
        vect1 = self.p3 - self.p1
        vect2 = self.p2 - self.p1

        areaMatrix = np.array( [ vect1, vect2])
        return 0.5*abs( np.linalg.det(areaMatrix))

# %%
p1 = Point(1,2)
p2 = Point(3,4)
p3 = Point(-1, 5)
t = Triangle(p1,p2,p3)
t.lengthSides()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-a617b8556aa5> in <module>
#       2 p2 = Point(3,4)
#       3 p3 = Point(-1, 5)
# ----> 4 t = Triangle(p1,p2,p3)
#       5 t.lengthSides()
#
# <ipython-input-60-374c496c0306> in __init__(self, p1, p2, p3, color)
#      10         # construimos los lados del triangulo
#      11         self.side1 = Segment(self.p1, self.p2)  # composition
# ---> 12         self.side2 = Segment(p2, p4)
#      13         self.side3 = Segment(self.p3, self.p1)
#      14
#
# NameError: name 'p4' is not defined

# %%
t.findArea() # a las 8:00 am

# %%
t.perimeter()
