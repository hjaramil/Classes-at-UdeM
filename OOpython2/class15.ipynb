# %% [markdown]
# #Generators (Generadores)

# %% [markdown]
# La idea de generadores es la idea de funciones que no retornan un valor sino que lo "permiten", la palabra es "yield". Es decir, son funciones que retornan iterador.

# %%
# ejemplo
def cubesL(n):
    return [i**3 for i in range(n+1)]

cubesL(4)
# Out:
# [0, 1, 8, 27, 64]

# %%
# para contrastar yo puedo definir un generador
def cubes(n):
    yield [i**3 for i in range(n+1)]

gen =cubes(4)
print(gen)
print(type(gen))
# Out:
# <generator object cubes at 0x7f5e22d5e850>
# <class 'generator'>

# %%
print(list(gen))
# Out:
# []

# %%
m=4
gen = cubes(m)
next(gen)
# Out:
# [0, 1, 8, 27, 64]

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-16-6e72e47198db> in <module>
# ----> 1 next(gen)
#
# StopIteration:

# %%
# si los quiero grandulados y no en bloque
def newCube(m):
    for i in range(m+1):
        yield i**3

m=4
gen = newCube(m)
print(gen)
# Out:
# <generator object newCube at 0x7f5e22d3c9d0>

# %%
m=4
for i in range(m+1):
    print(next(gen))
# Out:
# 0
# 1
# 8
# 27
# 64

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-21-6e72e47198db> in <module>
# ----> 1 next(gen)
#
# StopIteration:

# %%
# ganancias con generadorers (que son iteradores)
m=5000
L=[i**3 for i in range(m+1)]

gen=newCube(m)

# %%
L.__sizeof__()
# Out:
# 43016

# %%
gen.__sizeof__()
# Out:
# 96

# %%
m=5000000
L=[i**3 for i in range(m+1)]
gen=newCube(m)

# %%
L.__sizeof__()
# Out:
# 40215144

# %%
gen.__sizeof__()
# Out:
# 96

# %%
# un generador se puede crear de la misma
# forma que un list comprehension, pero con parentesis
gen = (i**3 for i in range(m+1))
gen
# Out:
# <generator object <genexpr> at 0x7f5e0cc99c50>

# %%
for i in range(10):
    print(next(gen))
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729

# %% [markdown]
# Convenciones de nombres:
#
# * Classes :camelcase. (todas las palabras separas con mayusculas)
# * metodos : dromedary case (todas las palabras internas con mayuscuals. Inicial minuscula
#
#
# ## Underscores:
# * Un guion bajo solo, indica una variable muda, comodin. Si ya existe respeta el valor, sino usa lo ultimo que habia en memoria
# * Un guion bajo de prefijo indica una variable privada. No se tocan las variables privadas, por regla. Respeto al programador
# * Dos guiones bajos de prefijo. Indica "name mangling". Ya lo vimos. La variable se oculta, pero hay forma de verla por que se crea otra variable pegada la clase donde esta definida.
# * Dos guiones bajos al comienzo y al final: "magic methods", "magic variables". Ya lo vimos.
# * En el medio de usan para separar palabras, en vez de CameCase. Por ejemplo "Camel_case".
# * Un guion al final. Es cuando las palabras se pueden confundir. Por ejemplo
# `True` es una palabra reserada del sistema. Si quiere usar la palabra `True` la puede usar con un guion bajo al final. Por ejemplo `True_` .
# Otro ejemplo: en el proyecto de ML, tiene la palabra $\lambda$ y $\lambda$_$.
#
# * No se usan palabras con dos guiones bajos al final.

# %%
for _ in range(10):
    print("hola")
# Out:
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola

# %%
a=5
a*7
print(_)

# %%
5*4
print(_)

# %%
20-10
print(_)

# %%
20*4
# Out:
# 80

# %%
print(_)
# Out:
# 80

# %%
for _ in range(10):
    print("hola")
# Out:
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola

# %%
print(_)
# Out:
# 9

# %%
5*4
# Out:
# 20

# %%
print(_)
# Out:
# 9

# %% [markdown]
# # Decorators: (Decoradores).
# Antes de introducir el concepto de decorares veamos el concepto de `closure`  (cerradura).
#
# Con ejemplos.
#
# Las funciones son **ciudadanos de primera clase** (functional programming paradigm).
#
# * Una funcion se le puede asignar a una variable
# * Una funcion puede retornar otra funcion
# * Una funcion puede tomar otra funcion como arguemento (composicion de funciones).

# %%
# funcion asignada aun una vairable
def sqr(a):
    return a**2

cuadrado = sqr

cuadrado(5)
# Out:
# 25

# %%
def myMessager(msg):

    def myMsg():
        print("my  message is", msg)  # la funcion "print" puede "msg" como argumento, msg es funcion

    return myMsg   # una funcion que retorna otra funcion

# %%
a = myMessager("hello")
print(a)
a()
# Out:
# <function myMessager.<locals>.myMsg at 0x7f1df9d7c3b0>
# my  message is hello

# %%
# %who
# Out:
# a	 cuadrado	 sqr

# %%
del(myMessage)

# %%
a()
# Out:
# my  message is hello

# %%
b = myMessage("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9160d58c3916> in <module>
# ----> 1 b = myMessage("hello")
#
# NameError: name 'myMessage' is not defined

# %% [markdown]
# Un container:
# 1. Tiene funciones anidadas (una dentro de otra).
# 2. La funcion interna debe referir el arugmento de la externa.
# 2. La funcion intererna debe ser retornada

# %% [markdown]
# La idea detras de los "enclosures" es que sirve como "wrapper". Es decir
# que si hay una funcion definida y queremos que se hagan mas cosas cuando
# ese funcion, pero no podemos **tocar** la original, escribimos un "wrapper" que modifica el trabajo de la original sin tacarla.

# %%
def myMessage():
    print("Hello")

def displayMessage(func):


    def inner():
        print("Executando", func.__name__, "funcion")
        func()
        print("ejecucion finalizada")

    return inner

testFunc = displayMessage(myMessage)
testFunc()
# Out:
# Executando myMessage funcion
# Hello
# ejecucion finalizada

# %%
testFunc()
# Out:
# Executando myMessage funcion
# Hello
# ejecucion finalizada

# %% [markdown]
# Esto mismo se puede hacer de otra forma.

# %%
@displayMessage
def myMessage():
    print("Hello")

def displayMessage(func):


    def inner():
        print("Executando", func.__name__, "funcion")
        func()
        print("ejecucion finalizada")

    return inner

# testFunc = displayMessage(myMessage)
#testFunc()
myMessage()
# Out:
# Executando myMessage funcion
# Hello
# ejecucion finalizada

# %% [markdown]
# Mas ejemplos con argumentos variables

# %%
def displayMessage(func):

    def inner(*args, **kwargs):
        print("Ejecutando", func.__name__, "funcion")
        return func(*args, **kwargs)
    return inner


@displayMessage
def myMessage():
    print("Hello")
    print("finished execution")
    return

@displayMessage
def myMessageWithArgs(name, age):
    print("name", name, "age", age)
    print("finishing execution")
    return

# %%
myMessage()
# Out:
# Ejecutando myMessage funcion
# Hello
# finished execution

# %%
myMessage("Jorge", 32)
# Out:
# Ejecutando myMessage funcion
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-fffcd26cbadd> in <module>
# ----> 1 myMessage("Jorge", 32)
#
# <ipython-input-38-9ef5f93aa9b5> in inner(*args, **kwargs)
#       3     def inner(*args, **kwargs):
#       4         print("Ejecutando", func.__name__, "funcion")
# ----> 5         return func(*args, **kwargs)
#       6     return inner
#       7
#
# TypeError: myMessage() takes 0 positional arguments but 2 were given

# %%
myMessageWithArgs("Jorge", 33)
# Out:
# Ejecutando myMessageWithArgs funcion
# name Jorge age 33
# finishing execution

# %% [markdown]
# ## Clases decoradores (lo mas comun es metodos como los de arriba)

# %%
class DisplayMessage(object):

    def __init__(self, func):
        self.func = func
        return

    def __call__(self, *args, **kwargs):
        print("Excecuting", self.func.__name__, "function")
        return self.func(*args, **kwargs)


@DisplayMessage
def myMessage():
    print("Hello")
    print("finished executing")
    return

@DisplayMessage
def myMessageWithArgs(name,age):
    print("name", name, "age", age)
    print("finishing execution")
    return

# %%
myMessage()
# Out:
# Excecuting myMessage function
# Hello
# finished executing

# %%
myMessageWithArgs("Jorge", 33)
# Out:
# Excecuting myMessageWithArgs function
# name Jorge age 33
# finishing execution

# %% [markdown]
# ### Otro ejemplo practico con division

# %%
def divide(a,b):
    return a/b

a=5
b=0
print(divide(a,b))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-51-98c634dda9d1> in <module>
#       4 a=5
#       5 b=0
# ----> 6 print(divide(a,b))
#       7
#
# <ipython-input-51-98c634dda9d1> in divide(a, b)
#       1 def divide(a,b):
# ----> 2     return a/b
#       3
#       4 a=5
#       5 b=0
#
# ZeroDivisionError: division by zero

# %%
# creaos una forma inteligente de dividir
# usando decoradores

def smart_div(func):
    def inner(a,b):
        print("Dividing", a, "by", b)
        print("my funcion name is", func.__name__)
        if b==0 :
            print("Cannot divide by zero")
            return
        return func(a,b)
    return inner

@smart_div
def divide(a,b):
    return a/b

a=5
b=0
print(divide(a,b))
# Out:
# Dividing 5 by 0
# my funcion name is divide
# Cannot divide by zero
# None

# %% [markdown]
# ## Revisitando OO: Metodos regulares, metodos de clase, metodos esticos.
#
# * Los metodos regulares son todos lo que llevan `self` y que hemos venido desarrollando en este curso. Nada nuevo
# * Los metodos de clase, tiene el **decorador** llamado `classmethod` y el primero argumento es `cls` (en vez de `self). Como la palabra lo dice, estos metodos son de clase. Es decir, todos los objetos (miles, millones, ...) inmediatamente obtienen este metodo de clase, por defecto, gratis.
#
# * Los metodos estaticos, son como las funciones comunes y corrientes que usamos antes de llegar al mundo OO.

# %%
#Ejemplo:

class Students():

    # variable de clase, se "pega" de todos los objetos de la clasee
    school = "Universidad de Medellin"

    # notas
    def __init__(self, name, g1, g2, g3):
        self.name = name
        self.g1=g1
        self.g2=g1
        self.g3=g3


    # average: promedio
    def average(self):  # metodo regular
        return (self.g1+self.g2+self.g3)/3.0

    # class metod (metodo de clase)
    @classmethod
    def info(cls):
        return cls.school


    # static metodo, como los de procedure programming paradigm
    @staticmethod
    def test_stat(a,b):
        school = "Universsidad Pontificial Bolivariana"
        print("This is a static method")
        print("My school is", school)
        print("La suma de a y b da")
        print(a+b)

# %%
# creamos objetos:
st1 = Students("Gloria", 3, 3.5, 3.2)
st2 = Students("Jorge", 4, 2, 1.0)
st1.school
# Out:
# 'Universidad de Medellin'

# %%
# imprima estudiante y promedio (metodo regular)
print(st1.name + " has ", round(st1.average(),2), "average")
print(st2.name + " has" , round(st2.average(),2), "average")
# Out:
# Gloria has  3.07 average
# Jorge has 3.0 average

# %%
st1.info()
d = st1.test_stat(3,5)
# Out:
# This is a static method
# My school is Universsidad Pontificial Bolivariana
# La suma de a y b da
# 8

# %%
from dill.source import getsource

# %%
def add(x,y):
    return x+y


print(getsource(add))
# Out:
# def add(x,y):
#     return x+y

# %%
import numpy as np
print(getsource(np.sqrt))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/dill/source.py in findsource(object)
#     156             if not isclass(object) and isclass(type(object)): # __class__
# --> 157                 file = getfile(module)
#     158                 sourcefile = getsourcefile(module)
#
# /usr/lib/python3.7/inspect.py in getfile(object)
#     665                     'code object was expected, got {}'.format(
# --> 666                     type(object).__name__))
#     667
#
# TypeError: module, class, method, function, traceback, frame, or code object was expected, got NoneType
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-702ace109826> in <module>
#       1 import numpy as np
# ----> 2 print(getsource(np.sqrt))
#
# /usr/local/lib/python3.7/dist-packages/dill/source.py in getsource(object, alias, lstrip, enclosing, force, builtin)
#     372     # get source lines; if fail, try to 'force' an import
#     373     try: # fails for builtins, and other assorted object types
# --> 374         lines, lnum = getsourcelines(object, enclosing=enclosing)
#     375     except (TypeError, IOError): # failed to get source, resort to import hooks
#     376         if not force: # don't try to get types that findsource can't get
#
# /usr/local/lib/python3.7/dist-packages/dill/source.py in getsourcelines(object, lstrip, enclosing)
#     343     If lstrip=True, ensure there is no indentation in the first line of code.
#     344     If enclosing=True, then also return any enclosing code."""
# --> 345     code, n = getblocks(object, lstrip=lstrip, enclosing=enclosing, locate=True)
#     346     return code[-1], n[-1]
#     347
#
# /usr/local/lib/python3.7/dist-packages/dill/source.py in getblocks(object, lstrip, enclosing, locate)
#     269     DEPRECATED: use 'getsourcelines' instead
#     270     """
# --> 271     lines, lnum = findsource(object)
#     272
#     273     if ismodule(object):
#
# /usr/local/lib/python3.7/dist-packages/dill/source.py in findsource(object)
#     161                 sourcefile = getsourcefile(object)
#     162         except (TypeError, AttributeError): # fail with better error
# --> 163             file = getfile(object)
#     164             sourcefile = getsourcefile(object)
#     165         if not sourcefile and file[:1] + file[-1:] != '<>':
#
# /usr/lib/python3.7/inspect.py in getfile(object)
#     664     raise TypeError('module, class, method, function, traceback, frame, or '
#     665                     'code object was expected, got {}'.format(
# --> 666                     type(object).__name__))
#     667
#     668 def getmodulename(path):
#
# TypeError: module, class, method, function, traceback, frame, or code object was expected, got ufunc

# %%
import inspect

def add(x,y):
    return x+y


squared = lambda x : x**2
print(inspect.getsource(add))
# Out:
# def add(x,y):
#     return x+y

# %%
print(inspect.getsource(squared))
# Out:
# squared = lambda x : x**2

# %%
class Foo:
    def foo():
        print("This is the foo() methodo")
        return

f = Foo()
print(inspect.getsource(f.foo))
# Out:
#     def foo():
#         print("This is the foo() methodo")
#         return

# %%
print(inspect.getsource(np.sqrt))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-51ca3006a178> in <module>
# ----> 1 print(inspect.getsource(np.sqrt))
#
# /usr/lib/python3.7/inspect.py in getsource(object)
#     971     or code object.  The source code is returned as a single string.  An
#     972     OSError is raised if the source code cannot be retrieved."""
# --> 973     lines, lnum = getsourcelines(object)
#     974     return ''.join(lines)
#     975
#
# /usr/lib/python3.7/inspect.py in getsourcelines(object)
#     953     raised if the source code cannot be retrieved."""
#     954     object = unwrap(object)
# --> 955     lines, lnum = findsource(object)
#     956
#     957     if istraceback(object):
#
# /usr/lib/python3.7/inspect.py in findsource(object)
#     766     is raised if the source code cannot be retrieved."""
#     767
# --> 768     file = getsourcefile(object)
#     769     if file:
#     770         # Invalidate cache if needed.
#
# /usr/lib/python3.7/inspect.py in getsourcefile(object)
#     682     Return None if no way can be identified to get the source.
#     683     """
# --> 684     filename = getfile(object)
#     685     all_bytecode_suffixes = importlib.machinery.DEBUG_BYTECODE_SUFFIXES[:]
#     686     all_bytecode_suffixes += importlib.machinery.OPTIMIZED_BYTECODE_SUFFIXES[:]
#
# /usr/lib/python3.7/inspect.py in getfile(object)
#     664     raise TypeError('module, class, method, function, traceback, frame, or '
#     665                     'code object was expected, got {}'.format(
# --> 666                     type(object).__name__))
#     667
#     668 def getmodulename(path):
#
# TypeError: module, class, method, function, traceback, frame, or code object was expected, got ufunc
