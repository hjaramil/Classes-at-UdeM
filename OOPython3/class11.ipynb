# %% [markdown]
# **Respuesta a la pregunta de Jorge**. Usar ```__dict__``` en la clase
# no en el objeto. Tambien puede usar ```vars()``` en vez de ```__dict___```.
#
# # Repaso de variables de clase y de instancia con un ejemplo.

# %%
class Car:
    brand="Toyota"
    model="Corolla"
    year=2014

# %%
# formas de extaer datos de una clase
# operador punto

myCar = Car()
print("brand=%s, model=%s, year=%s\n"%(myCar.brand, myCar.model, myCar.year))
# Out:
# brand=Toyota, model=Corolla, year=2014

# %%
vars(myCar)  # solo funciona con las de instancia
# Out:
# {}

# %%
vars(Car)  # la uso en la clase, si funciona con un poco mas de informacion
# Out:
# mappingproxy({'__module__': '__main__',
#               'brand': 'Toyota',
#               'model': 'Corolla',
#               'year': 2014,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
# formas de alterar o cambiar variables
myCar.brand="Nissan"
print(myCar.brand)
# Out:
# Nissan

# %%
# usando setattr()
setattr(myCar, "year", 2020)  # a nivel de objeto
print(myCar.year)
# Out:
# 2020

# %%
# puedo capturar el atributo con getattr
getattr(myCar,"year")
# Out:
# 2020

# %%
## Borrado de variables
myCar.model
# Out:
# 'Corolla'

# %%
delattr(Car, "model")
print(myCar.model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-1e45d3af4b3c> in <module>
#       1 delattr(Car, "model")
# ----> 2 print(myCar.model)
#
# AttributeError: 'Car' object has no attribute 'model'

# %%
# borrar un objeto
del(myCar)
myCar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a51710f3c72b> in <module>
#       1 # borrar un objeto
#       2 del(myCar)
# ----> 3 myCar
#
# NameError: name 'myCar' is not defined

# %%
# borremos la clase
del(Car)
myCar = Car()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a451ec42f164> in <module>
#       1 # borremos la clase
#       2 del(Car)
# ----> 3 myCar = Car()
#
# NameError: name 'Car' is not defined

# %%
# creamos la clase de nuevo y generamos un objeto
class Car:
    brand="Toyota"
    model="Corolla"
    year=2014

myCar = Car()

# %%
# borramos el objeto
del(myCar)
myCar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-24a830f5c58a> in <module>
#       1 # borramos el objeto
#       2 del(myCar)
# ----> 3 myCar
#
# NameError: name 'myCar' is not defined

# %%
myCar=Car()
myCar

# %% [markdown]
# ## Explorar dentro de la clase. Pregunta de Jorge

# %%
# usando    dir
print(dir(myCar)) # no es muy bueno. Muestra todos los atributos pero nos valores
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'brand', 'model', 'year']

# %%
# dict
myCar.__dict__   # vacio. Pues __dict__ y vars()  trabajan en variables de instancia
# Out:
# {}

# %%
# vamos a ver como hacer trabajar __dict__ con variables de clase
setattr(myCar, 'year', 2020)
setattr(myCar, 'model', 'Sequoia')
myCar.__dict__
# Out:
# {'year': 2020, 'model': 'Sequoia'}

# %%
vars(myCar)
# Out:
# {'year': 2020, 'model': 'Sequoia'}

# %%
# el uso de __dict__ directamente en la case funciona
Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'brand': 'Toyota',
#               'model': 'Corolla',
#               'year': 2014,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
vars(Car)
# Out:
# mappingproxy({'__module__': '__main__',
#               'brand': 'Toyota',
#               'model': 'Corolla',
#               'year': 2014,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
# otra forma es con inspect
import inspect
inspect.getmembers(Car) # es un "overkill".
# Out:
# [('__class__', type),
#  ('__delattr__', <slot wrapper '__delattr__' of 'object' objects>),
#  ('__dict__',
#   mappingproxy({'__module__': '__main__',
#                 'brand': 'Toyota',
#                 'model': 'Corolla',
#                 'year': 2014,
#                 '__dict__': <attribute '__dict__' of 'Car' objects>,
#                 '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#                 '__doc__': None})),
#  ('__dir__', <method '__dir__' of 'object' objects>),
#  ('__doc__', None),
#  ('__eq__', <slot wrapper '__eq__' of 'object' objects>),
#  ('__format__', <method '__format__' of 'object' objects>),
#  ('__ge__', <slot wrapper '__ge__' of 'object' objects>),
#  ('__getattribute__', <slot wrapper '__getattribute__' of 'object' objects>),
#  ('__gt__', <slot wrapper '__gt__' of 'object' objects>),
#  ('__hash__', <slot wrapper '__hash__' of 'object' objects>),
#  ('__init__', <slot wrapper '__init__' of 'object' objects>),
#  ('__init_subclass__', <function Car.__init_subclass__>),
#  ('__le__', <slot wrapper '__le__' of 'object' objects>),
#  ('__lt__', <slot wrapper '__lt__' of 'object' objects>),
#  ('__module__', '__main__'),
#  ('__ne__', <slot wrapper '__ne__' of 'object' objects>),
#  ('__new__', <function object.__new__(*args, **kwargs)>),
#  ('__reduce__', <method '__reduce__' of 'object' objects>),
#  ('__reduce_ex__', <method '__reduce_ex__' of 'object' objects>),
#  ('__repr__', <slot wrapper '__repr__' of 'object' objects>),
#  ('__setattr__', <slot wrapper '__setattr__' of 'object' objects>),
#  ('__sizeof__', <method '__sizeof__' of 'object' objects>),
#  ('__str__', <slot wrapper '__str__' of 'object' objects>),
#  ('__subclasshook__', <function Car.__subclasshook__>),
#  ('__weakref__', <attribute '__weakref__' of 'Car' objects>),
#  ('brand', 'Toyota'),
#  ('model', 'Corolla'),
#  ('year', 2014)]

# %%
## Variables de instancia
class Car:
    brand="Toyota"
    model="Corolla"
    year=2014

    def __init__(self, color='yellow'):
        self.color=color
        return

    def stop(self):
        print("please stop")
        return

# %%
c = Car()
c.color
# Out:
# 'yellow'

# %%
# setatt() en variables de instance
setattr(c, "color", "blue")
c.color
# Out:
# 'blue'

# %%
vars(c)
# Out:
# {'color': 'blue'}

# %%
vars(Car)
# Out:
# mappingproxy({'__module__': '__main__',
#               'brand': 'Toyota',
#               'model': 'Corolla',
#               'year': 2014,
#               '__init__': <function __main__.Car.__init__(self, color='yellow')>,
#               'stop': <function __main__.Car.stop(self)>,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
# borrar atributos de instancia
delattr(c, 'color')  # se borra el atributo a nivel de objeto
vars(c)
# Out:
# {}

# %%
d = Car()
d.color # en objetos nuevos no se pierde el atributo que se borro arriba
# Out:
# 'yellow'

# %%
del(d)
d.color
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b04889cf2b84> in <module>
#       1 del(d)
# ----> 2 d.color
#
# NameError: name 'd' is not defined

# %%
c=Car()
c.color

# %%
del(c.color)
c.color

# %%
# Borremos metodos
e = Car()
e.stop()
# Out:
# please stop

# %%
del Car.stop
e.stop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-2c32b6274f43> in <module>
#       1 del Car.stop
# ----> 2 e.stop()
#
# AttributeError: 'Car' object has no attribute 'stop'

# %%
f = Car()
f.stop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-1be6c36ad03c> in <module>
#       1 f = Car()
# ----> 2 f.stop()
#
# AttributeError: 'Car' object has no attribute 'stop'

# %%
## Variables de instancia
class Car:
    brand="Toyota"
    model="Corolla"
    year=2014

    def __init__(self, color='yellow'):
        self.color=color
        return

    def stop(self):
        print("please stop")
        return

# %%
e=Car()
del(e, "stop")
e.stop()
# Out:
#   File "<ipython-input-34-ade81be77e2d>", line 2
#     del(e, "stop")
#        ^
# SyntaxError: cannot delete literal

# %%
f = Car()
f.stop()
# Out:
# please stop

# %%
# cambiamos una variable de instancia
f.color
# Out:
# 'yellow'

# %%
setattr(Car, "color", "blue")  # el color es de instancia y solo se deja cambiar a nivel de objeto.
f.color
# Out:
# 'yellow'

# %%
f.brand
# Out:
# 'Toyota'

# %%
setattr(Car, "brand", "Nissan") # pienso que los objetos no se deben cambiar desde la fabrica.
f.brand
# Out:
# 'Nissan'

# %% [markdown]
# # Entonces cuando debemos usar variables de clase?
# Cuando estas no cambien, o el cambio no sea lento

# %%
# clase cilindro
class Cylinder:
    pi = 3.14159  # variable de clase. Nunca cambia


    def __init__(self, radius, height):
        self.radius = radius
        self.height = height
        return

    def volume(self):
        return self.pi*self.radius**2*self.height

    def surfaceArea(self):
        return 2*self.pi*self.radius**2 + 2*self.pi*self.radius*self.height

myCylinder = Cylinder(2,3)

print("Volume of my cylinder", myCylinder.volume())
print("Surface area of my cylinder", myCylinder.surfaceArea())
# Out:
# Volume of my cylinder 37.699079999999995
# Surface area of my cylinder 62.831799999999994

# %%
myC1 = Cylinder(2,3)
myC2 = Cylinder(5,4)
myC3 = Cylinder(2,2)


print(myC1.__dict__, myC1.pi)
print(myC2.__dict__, myC2.pi)
print(myC3.__dict__, myC3.pi)
# Out:
# {'radius': 2, 'height': 3} 3.14159
# {'radius': 5, 'height': 4} 3.14159
# {'radius': 2, 'height': 2} 3.14159

# %%
# tratemos de borrar la vairbale pi de la clase
delattr(Cylinder, "pi")

# %%
print(Cylinder.pi)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-a08c34f26bb6> in <module>
# ----> 1 print(Cylinder.pi)
#
# AttributeError: type object 'Cylinder' has no attribute 'pi'

# %%
delattr(Cylinder, "radius") # no puedo borrar de la clase un atributo de objeto
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-bc6586043806> in <module>
# ----> 1 delattr(Cylinder, "radius") # no puedo borrar de la clase un atributo de objeto
#
# AttributeError: radius

# %%
delattr(myCylinder, "radius")

# %%
myCylinder.__dict__
# Out:
# {'height': 3}

# %%
Cylinder.pi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-9208a7a83d04> in <module>
# ----> 1 Cylinder.pi
#
# AttributeError: type object 'Cylinder' has no attribute 'pi'

# %% [markdown]
# ## Contar referencias de objetos en una clase

# %%
class Car:
    pass

# %%
# contemos referencias
import sys
cars = Car()
sys.getrefcount(cars)
# Out:
# 2

# %%
vehicle = cars # se incrementa
sys.getrefcount(cars)
# Out:
# 4

# %%
help(sys.getrefcount)
# Out:
# Help on built-in function getrefcount in module sys:
#
# getrefcount(object, /)
#     Return the reference count of object.
#
#     The count returned is generally one higher than you might expect,
#     because it includes the (temporary) reference as an argument to
#     getrefcount().

# %%
def printId(myObj):
    print(id(myObj))
    return

printId(cars)
# Out:
# 140035061363328

# %%
sys.getrefcount(cars)
# Out:
# 5

# %%
b=cars
sys.getrefcount(cars)
# Out:
# 6

# %%
# Rebajar la cuenta
cars2 = cars
print(sys.getrefcount(cars))

cars2=5.0 # rebaja por sobre-escritura
sys.getrefcount(cars)
# Out:
# 8
# 7

# %%
# rebaja por borrado
myList = [cars]
myList2 = [cars]
sys.getrefcount(cars)
# Out:
# 9

# %%
del(myList)
sys.getrefcount(cars)
# Out:
# 9

# %%
myList2 = None
print(sys.getrefcount(cars))
# Out:
# 8
