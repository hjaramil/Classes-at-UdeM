# %% [markdown]
# ## Override
# Cambia el comportamiento de una funcion.
# Expliquemos el concepto con un ejemplo

# %%
class Person:
    def __init__(self, name, age, inBar):
        self.name = name
        self.age = age
        self.inBar = inBar
        return

    def adult(self):
        return self.age >= 18  #en Colombia

    def fineBarOwner(self):
        if not self.adult() and self.inBar:
            print(f"{self.name}, you should not be here")
            print("You and the bar onwer are in trouble")
        else:
            print("%s, you are fine: You are a good guy"%self.name)

        return

class Drinker(Person):
    def adult(self):
        return self.age >= 21  # en USA


    def fieBarOwner(self):
        super().fineBarOwner()
        return


jesus = Person("Jesus", 15, True)
print(jesus.__dict__)
jesus.fineBarOwner()
# Out:
# {'name': 'Jesus', 'age': 15, 'inBar': True}
# Jesus, you should not be here
# You and the bar onwer are in trouble

# %%
rob = Person("Roberto", 18, True)
print(vars(rob))
rob.fineBarOwner()
# Out:
# {'name': 'Roberto', 'age': 18, 'inBar': True}
# Roberto, you are fine: You are a good guy

# %% [markdown]
# ## Multi-level inheritance (Herencia multinivel)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Analogica matematica:
#
# $$a[ x ( \alpha_1 + \beta_1) + y(\alpha_2 + \beta_2) + z(\alpha_3 + \beta_3)] = ax\alpha_1 + ax \beta_1 + ay \alpha_2 + ay \beta_2 + az \alpha_3 + az \beta_3  $$
