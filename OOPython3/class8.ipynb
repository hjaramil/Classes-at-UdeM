# %% [markdown]
# Que pasa con los 53 bits en IEEE?
# # Object Oriented Python

# %% [markdown]
# # Object Oriented Python (OOP).
#
# Una tabla de contenido
#
# * Re-visitiar concepto de objeto y clase
# * Encapsulation (Encapsulacion)
# * Association (Asociacion)
#     * Composition (composicion)
#     * Aggregation (agragación)
#
# * Inheritance (herencia)
# * Polimorfismo
# * Abstraccion
#
# Repaso
#
# ## Clases y Objetos
# Que es una clase? Una clase es un mapa que describe objetos.
# Un objeto es algo que se crea de ese mapa. Una clase genera tantos
# objetos como queramos. El objeto es "concreto" . Es una "concrecion" de la clase, en ingles "instantiation" (instanciacion) de la clase.
# La clase es una "abstraccion" del objeto.
#
#
# La clase tiene
#
# * Atributos: Sustantivos y adjetivos. Se llaman **estados** de la clase
# * Metodos: Verbos (metodos). **comportamientos** (behavior).
#
# Vamos a la practica.
#
# ### La clase mas simple
# La clase vacia.
# Para que una clase vacia.
#
# [ver este link](https://stackoverflow.com/questions/61243808/whats-the-usage-of-empty-class-in-python) .

# %%
# la clase vacia
class Car:
    pass

myCar = Car() # instanciacion, este ya es un objeto
print(type(myCar))  # verifique es en realidad es de la case Car
print(id(myCar)) # memoria en enteros
print(myCar)  # me imprime la informacion de donde esta pegado y la memoria en hex>
# Out:
# <class '__main__.Car'>
# 139693614399600
# ...

# %%
hex(139693614399600)
# Out:
# '0x7f0cf4438070'

# %%
0x7f0cf4438070
# Out:
# 139693614399600

# %% [markdown]
# Todo en Python son objetos. Hasta las clases son objetos.

# %%
class Car:
    pass

print(Car.__name__)
# Out:
# Car

# %%
dir(Car)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %% [markdown]
# Fijense que el atributo "__name__" no aparece bajo "dir". Por que?
# [vea este link](https://stackoverflow.com/questions/7096132/why-does-cls-name-not-appear-in-dir).
#
#
#
# ## Para que clases?
#
# Ilustramos con un ejemplo cuando las clases estorban

# %%
def sqr(x):
    return x**2

print(sqr(3))
print(sqr(4))
# Out:
# 9
# 16

# %%
class Square:
    side = 2  # el parametro por defecto

    def sqr(self):
        return self.side**2   # encuentra el area del cuadrado

# crear objeto
mySqr =Square()
mySqr.side=3 # cambio el parametro por defecto
a = mySqr.sqr()
print(a)
mySqr.side = 4
print(mySqr.sqr())
# Out:
# 9
# 16

# %% [markdown]
# Que es **self** ?
# El self es la memoria del objeto.
# Verifiquemos esto

# %%
class Square:
    side = 2

    def sqr(self):
        print("memoria del objeto ", id(self))
        print()
        return self.side**2

mySqr = Square()
mySqr.sqr()
print(id(mySqr))
# Out:
# memoria del objeto  139693614402528
#
# 139693614402528

# %%
class Square:
    side = 2

    def sqr(self, a):
        print("memoria del objeto ", id(self))
        print()
        print(a)
        return self.side**2


a=5
mySqr = Square()
mySqr.sqr(a)
print(id(mySqr))
# Out:
# memoria del objeto  139693004841648
#
# 5
# 139693004841648

# %%
class Square:
    side = 2

    def sqr(self):
        print("memoria del objeto ", id(self))
        print()
        print(a)
        return self.side**2


a=5
mySqr = Square()
mySqr.sqr(a)
print(id(mySqr))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-24da2016b4f2> in <module>
#      11 a=5
#      12 mySqr = Square()
# ---> 13 mySqr.sqr(a)
#      14 print(id(mySqr))
#
# TypeError: sqr() takes 1 positional argument but 2 were given

# %% [markdown]
# Por que la palabra **self**. Realmente no es necesaria,
# por ejemplop cambiemos **self**por **this**

# %%
class Square:
    side = 2

    def sqr(this, a):
        print("memoria del objeto ", id(this))
        print()
        print(a)
        return this.side**2


a=5
mySqr = Square()
mySqr.sqr(a)
print(id(mySqr))
# Out:
# memoria del objeto  139693005199776
#
# 5
# 139693005199776

# %%
class Square:
    side = 2

    def sqr(elefante, a):
        print("memoria del objeto ", id(elefante))
        print()
        print(a)
        return elefante.side**2


a=5
mySqr = Square()
mySqr.sqr(a)
print(id(mySqr))
# Out:
# memoria del objeto  139693004841600
#
# 5
# 139693004841600

# %%
class Car:
    pass

print(isinstance(Car, type))
# Out:
# True

# %%
dir(type)
# Out:
# ['__abstractmethods__',
#  '__base__',
#  '__bases__',
#  '__basicsize__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dictoffset__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__flags__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__instancecheck__',
#  '__itemsize__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mro__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__prepare__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasscheck__',
#  '__subclasses__',
#  '__subclasshook__',
#  '__text_signature__',
#  '__weakrefoffset__',
#  'mro']

# %% [markdown]
# ## metodo   \_\_init\_\_
#
# Es util, cuando se crea una clase, incluir parametros que la clase va a necesitar siempre y que no hay re-asignarlos.
#
# Por ejemplo un carro siempre tiene 4 llantas y no queremos re-asignar este valor. Todos esos parametros, por defecto, que no queremos re-asignar van en el metodo \_\_init\_\_ .
#
# Comparando con C++ y Java, alli a este metodo lo llaman el **constructor**. Ahora bien en C++, por cada constructor hay
# un **destructor**. Python (como Java) tienen garbage collection y ellos se encargan de destruir los objetos cuando ya no se necesitan.
#
# Python tambien tiene un destructor (no se usa mucho) que se llama
# **del()**. Lo vamos a estudiar mas adelante.
#
# Visitando mas el interior de Python existe un metodo llamado **new()** que genera objetos.
#
#
# ### new()
# Hay algo en la ciencia de la programacion que se llama **signature**.
# El signature, se refiere a un metodo, tiene tres elemetos
#
# * El nombre del metodo
# * Los argumentos (entre parentesis)
# * El tipo de retorno (para C, C++, Java, etc. No python
#
# En el caso de new(), el "signature" es
#
# ```  object.__new__(class, arguments) ```
#
#
#
#
#
# Veamos ejemplos del uso del **new()**

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self. model = model
        self.year = year
        return

myCar = Car("Toyota", "Corolla", 2010)

# %%
myCar.__dict__
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'year': 2010}

# %%
# como usar el new() una nueva herramienta
class Car:
    def __new__(cls, brand, model, year):
        print(f'Creating a new {cls.__name__} object...')
        obj = object.__new__(cls)
        print(id(obj))
        return obj


    def __init__(self, brand, model, year):
        print(f"inicializador del objeto Car")
        self.brand = brand
        self.model = model
        self.year = year
        return

myCar = Car('Toyota', 'Corolla', 2010)
myCar2 = Car("Nissan", "Sentra", 2020)
print(id(myCar))
# Out:
# Creating a new Car object...
# 139692866674944
# inicializador del objeto Car
# Creating a new Car object...
# 139692866676336
# inicializador del objeto Car
# 139692866674944

# %%
myCar.__dict__
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'year': 2010}

# %%
myCar2.__dict__
# Out:
# {'brand': 'Nissan', 'model': 'Sentra', 'year': 2020}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-9925d326e802> in <module>
# ----> 1 myCar[0]
#
# TypeError: 'Car' object is not subscriptable

# %%
dir(myCar)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'brand',
#  'model',
#  'year']

# %% [markdown]
# Ejemplo: modifique la clase Square para incluir nuevos parametros.
# Por ejemplo si estuvieramos desarrollando un paquete de dibujar (por ejemplo PowerPoint) incluir parametros como color, centro, etc

# %%
# ultimo ejemplo
class Square:
    
    def __init__(self, side, color, center):
        self.side = side
        self.color = color
        self.center = center
        return


    def sqr(self):
        return self.side**2

mySqr = Square(2, "amarillo", (3,4))
print("area del cuadrado es", mySqr.sqr())
# Out:
# area del cuadrado es 4

# %%
mySqr.__dict__
# Out:
# {'side': 2, 'color': 'amarillo', 'center': (3, 4)}
