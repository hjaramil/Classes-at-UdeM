# %% [markdown]
# ## Ejemplo de donde se genera un FloatingPointError.
# Ver la documentacion en numpy errstate

# %%
import numpy as np
help(np.errstate)
# Out:
# Help on class errstate in module numpy:
#
# class errstate(contextlib.ContextDecorator)
#  |  errstate(*, call=<numpy.core._ufunc_config._unspecified object at 0x7f3824a009a0>, **kwargs)
#  |
#  |  errstate(**kwargs)
#  |
#  |  Context manager for floating-point error handling.
#  |
#  |  Using an instance of `errstate` as a context manager allows statements in
#  |  that context to execute with a known error handling behavior. Upon entering
#  |  the context the error handling is set with `seterr` and `seterrcall`, and
#  |  upon exiting it is reset to what it was before.
#  |
#  |  ..  versionchanged:: 1.17.0
#  |      `errstate` is also usable as a function decorator, saving
#  |      a level of indentation if an entire function is wrapped.
#  |      See :py:class:`contextlib.ContextDecorator` for more information.
#  |
#  |  Parameters
#  |  ----------
#  |  kwargs : {divide, over, under, invalid}
#  |      Keyword arguments. The valid keywords are the possible floating-point
# ...

# %%
with np.errstate(invalid='raise'):
    np.sqrt(-1)
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-5-c434a2b91c95> in <cell line: 1>()
#       1 with np.errstate(invalid='raise'):
# ----> 2     np.sqrt(-1)
#
# FloatingPointError: invalid value encountered in sqrt

# %%
2.5**4000
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-7-9f0bf1b398e5> in <cell line: 1>()
# ----> 1 2.5**4000
#
# OverflowError: (34, 'Numerical result out of range')

# %% [markdown]
# Tanto Jupyter/Jupyter-lab como Google Colaboratory emulan un sistema operativo. Puede ser Windows o Linux. Vamos a ver estas plataformas interactuan con los sistemas operativos. Yo uso Linux.
# Si estan interesados en como interectua con Windows.
#
# [para Windows, hacer click aca](https://www.analyticsvidhya.com/blog/2021/05/how-to-interact-with-operating-system-using-python-and-jupyter-notebook/)
#
# Emigro a Jupyter-lab

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pwd
# Out:
# '/content'

# %%
# !cd /

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
pwd
# Out:
# '/content/gdrive'

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
#  20160619_141407.jpg
#  20160619_145344.jpg
# '2021 (1).gsheet'
# '2021 (2).gsheet'
# '2021 (3).gsheet'
# '2021 (4).gsheet'
#  2021.gsheet
#  20221001_013119350_001304500200176797.pdf
#  56a.wxm
# '5a26731139f97 (1).pdf'
#  5a34003cf3e08.pdf
# 'Acta divorcio Herman IMG.pdf'
#  additionalColabNotebooks/
#  ambient_rec_20160617_173000.amr
#  analisis_numerico.pdf
#  andreina/
#  animline-seaborn.gif
# 'ARBOL GENEALOGICO COMPLETO JARAMILLO BOTERO ESPAÑA-ITALIA.pdf'
# 'Ascendencia de papa pacho Francisco Emilio Jaramillo Uribe.pdf'
#  Backups/
#  bisect.pdf
#  carpeta18.doc
#  Cartas/
#  class13.ipynb
#  Cloud/
#  ColabNotebooks/
# 'COORDENAS CILÍNDRICAS.ipynb'
# 'Copy of Copy of Email Permutator (1).gform'
# 'Copy of Copy of Email Permutator.gform'
# 'Copy of Copy of Email Permutator.gsheet'
# 'Copy of Email Permutator (1).gform'
# 'Copy of Email Permutator (1).gsheet'
# 'Copy of Email Permutator (2).gform'
# 'Copy of Email Permutator (3).gform'
# 'Copy of Email Permutator.gform'
# ...

# %%
# !gedit otherTest.py
# Out:
# /bin/bash: gedit: command not found

# %%
run otherTest.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'otherTest.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-7fbddfc9af25> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', 'otherTest.py')
#
# ...

# %%
ls o*
# Out:
# output.xlsx

# %%
pwd
# Out:
# '/content/gdrive/MyDrive'

# %%
pwd
# Out:
# '/content/gdrive/MyDrive'

# %%
cd ColabNotebooks
# Out:
# /content/gdrive/MyDrive/ColabNotebooks

# %%
# !find . -name otherTest.py
# Out:
# ./OOP3/otherTest.py

# %%
cd OOP3
# Out:
# /content/gdrive/MyDrive/ColabNotebooks/OOP3

# %%
run otherTest.py
# Out:
# 5

# %%
ls
# Out:
# aggregation.ipynb  class11.ipynb  class22.ipynb  class6/
# bit53.ipynb        class12.ipynb  class23.ipynb  class6.ipynb
# Clase1/            class13.ipynb  class24.ipynb  class7.ipynb
# Clase13/           class15.ipynb  class25.ipynb  class8.ipynb
# clase14.ipynb      class16.ipynb  class26.ipynb  class9.ipynb
# Clase1.ipynb       class17.ipynb  class3.ipynb   otherTest.py
# Clase2/            class18.ipynb  Class4/        testReadDrive.ipynb
# Clase2.ipynb       class19.ipynb  class4.ipynb
# Clase3/            class20.ipynb  Class5/
# class10.ipynb      class21.ipynb  class5.ipynb

# %%
ls -lt
# Out:
# total 2820
# -rw------- 1 root root   26969 May  4 15:26 class26.ipynb
# -rw------- 1 root root      18 May  4 15:22 otherTest.py
# -rw------- 1 root root  107917 May  2 16:52 class25.ipynb
# -rw------- 1 root root  160056 May  2 01:12 class24.ipynb
# -rw------- 1 root root   27221 Apr 25 16:09 class23.ipynb
# -rw------- 1 root root    6163 Apr 20 16:38 class22.ipynb
# -rw------- 1 root root   12141 Apr 18 15:40 class21.ipynb
# -rw------- 1 root root  116154 Apr 13 15:42 class20.ipynb
# -rw------- 1 root root   71079 Apr 12 19:15 class19.ipynb
# -rw------- 1 root root   18963 Mar 30 15:31 class18.ipynb
# -rw------- 1 root root   16843 Mar 30 15:11 class17.ipynb
# -rw------- 1 root root   17256 Mar 23 15:44 class16.ipynb
# -rw------- 1 root root   34922 Mar 21 16:31 class15.ipynb
# -rw------- 1 root root    9583 Mar 20 23:28 aggregation.ipynb
# -rw------- 1 root root    8592 Mar 17 21:51 clase14.ipynb
# -rw------- 1 root root   57901 Mar 14 15:49 class13.ipynb
# ...

# %%
cat otherTest.py
# Out:
# a=2
# b=3
# print(a+b)

# %%
# !more otherTest.py
# Out:
# a=2
# b=3
# print(a+b)

# %%
# %load otherTest.py

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/ColabNotebooks/OOP3'

# %%
import sys
sys.path.append(r'/content/gdrive/MyDrive/ColabNotebooks/OOP3')

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/gdrive/MyDrive/ColabNotebooks/OOP3']

# %%
cat otherTest.py
# Out:
# a=2
# b=3
# print(a+b)
# def f(x):
#     return x**x

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/ColabNotebooks/OOP3'

# %%
import otherTest as ot

a=3
ot.f(a)
# Out:
# 27

# %%
cd ..
# Out:
# /content/gdrive/MyDrive/ColabNotebooks

# %%
cat otherTest.py
# Out:
# cat: otherTest.py: No such file or directory

# %%
import otherTest as ot

a=3
ot.f(a)
# Out:
# 27
