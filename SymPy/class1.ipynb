# %% [markdown]
# # Python simbolico (Symbolic Python: SymPy).
# ## Introduccion.
# Por que ```SymPy```
#
# Hay un lista grande de software para el desarrollo simbolico algebraico.
# Yo particularmente he tabajado con ```Mathematica``` ,```Maple```, ```Maxima```, ```SymPy```. ```WolframAlpha``` es una gran herramienta simbolica.
#
# Auque estos paquetes son poderosos, casi todos cuestan. ```Python``` es gratis y te permeite trabajar con Cuadernillos (cuadernos, notebooks y esto incluye el gran GoogleColab).
#
#
# ### Como se evalua este curso.
# En cada clase hay **actividades**. Algunas de ellas son rapidas y se pueden hacer directamente en la clase, otras no tanto y se dejan como tarea hasta la proxima clase. Si yo pienso, o usted me convece de que la actividad es muy compleja, entonces la pongo "bonus". Si la hace subo 3 decimas a la nota final, si no la hace, no pasa nada.  No hay excusa (en condiciones normales) para no hacer las tareas.
#
# * Use lo que sabe.
# * Use lo que esta aprendiendo en clase y las herrameintas:
#     * Google colab notebook.
#     * La grabacion de la clase .
#     * GitHub.
#     * Google (para buscar): ```StackOverflow```, ```StatExchange```.
#     * ChatGPT.
#     * Preguntema a mi, o algun amigo.
#
#
# ### Microcurrilo:
# * Aritmetica (hoy)
# * Algebra (3 cuadernos)
# * Cálculos
#     * Integral
#     * Diferencial
#     * Varias variables.
#
# * Ecuaciones Diferenciales
#
# ### Qhe no vemos en este curso que es intersante
#
# * Analisis complejo
# * Algebra lineal (aunque en este curso se ven algunas cosas de algebra lineal , como solucion de ecuaciones)
# * Analisis de Fourier
# * Teoria tranformadas: Fourier, Laplace, Hankel, Mellin, Sine, Cosine.
# * Teoria de distribuciones
# * Funciones especiales (Gamma, Beta, etc).

# %% [markdown]
# # Aritmetica: Fracciones, fracciones continuadas, precision y otros topicos
#
# ## Como ayuda.

# %%
import sympy as sm
# sm. con solo poner el punto aparecen todas las posibilidades, Cuales?

listadeprogramas=dir(sm)
len(listadeprogramas)
# print(listadeprogramas)  # quite el comentario para ver la lista de herramientas que ofrece SymPy
# Out:
# 932

# %%
# help
help(sm.AlgebraicNumber)
# Out:
# Help on class AlgebraicNumber in module sympy.core.numbers:
#
# class AlgebraicNumber(sympy.core.expr.Expr)
#  |  AlgebraicNumber(expr, coeffs=None, alias=None, **args)
#  |
#  |  Class for representing algebraic numbers in SymPy.
#  |
#  |  Symbolically, an instance of this class represents an element
#  |  $\alpha \in \mathbb{Q}(\theta) \hookrightarrow \mathbb{C}$. That is, the
#  |  algebraic number $\alpha$ is represented as an element of a particular
#  |  number field $\mathbb{Q}(\theta)$, with a particular embedding of this
#  |  field into the complex numbers.
#  |
#  |  Formally, the primitive element $\theta$ is given by two data points: (1)
#  |  its minimal polynomial (which defines $\mathbb{Q}(\theta)$), and (2) a
#  |  particular complex number that is a root of this polynomial (which defines
#  |  the embedding $\mathbb{Q}(\theta) \hookrightarrow \mathbb{C}$). Finally,
#  |  the algebraic number $\alpha$ which we represent is then given by the
# ...

# %%
# Otra forma es con el signo de interrogacion
??sm.AlgebraicNumber

# %% [markdown]
# ### Primeros ejemplos con fracciones (precision infinta)

# %%
from sympy import Rational
a = Rational(1,2)
b = Rational(3,4)
c=a+b
print(a,b,c)
display(f"Solucion de sumar {a} + {b}  es {c}")
display("Solucion de sumar 1/2 + 1/3  es ",c)
# Out:
# 1/2 3/4 5/4
# 'Solucion de sumar 1/2 + 3/4  es 5/4'
# 'Solucion de sumar 1/2 + 1/3  es '
# 5/4

# %%
print(1/3) #no es precision finita
# Out:
# 0.3333333333333333

# %%
a=1/3
b=3/4
c=a+b
print(a,b,c)
# Out:
# 0.3333333333333333 0.75 1.0833333333333333

# %%
a=1/3
b=Rational(1,3)
a-b # por que si a esta truncado
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a309de075ed4> in <cell line: 2>()
#       1 a=1/3
# ----> 2 b=Rational(1,3)
#       3 a-b # por que si a esta truncado
#
# NameError: name 'Rational' is not defined

# %%
a == b
# Out:
# False

# %%
print(a)
display(b)
# Out:
# 0.3333333333333333
# 1/3

# %%
type(a)
# Out:
# float

# %%
type(b)
# Out:
# sympy.core.numbers.Rational

# %%
d = Rational(0.5)
display(d)
# Out:
# 1/2

# %%
e= Rational(0.2)
display(e)
# Out:
# 3602879701896397/18014398509481984

# %% [markdown]
# ### Actividad 1: Por que no arrojó 1/5 ? y Justo  este numero tan grande

# %% [markdown]
# ### Potencias

# %%
from sympy import symbols # esta tal vez la instruccion mas comun estas clases
x = symbols('x')
x**(3/2)
# Out:
# x**1.5

# %%
x**(Rational(1.5))
# Out:
# x**(3/2)

# %%
from sympy import simplify
simplify(e)
# Out:
# 3602879701896397/18014398509481984

# %%
from fractions import Fraction
print(Fraction(0.2))
# Out:
# 3602879701896397/18014398509481984

# %%
# casting
float(e)
# Out:
# 0.2

# %%
a= Rational(1,2)
display(a)
# Out:
# 1/2

# %%
b=sm.sqrt(2)
b
# Out:
# sqrt(2)

# %%
display ( (a*b)**2)
# Out:
# 1/2

# %%
print(f"a = {a}, b={b}")
# Out:
# a = 1/2, b=sqrt(2)

# %%
sm.sqrt(4)
# Out:
# 2

# %% [markdown]
# Construyamos la siguiente operacion:
#
# $$2 \sqrt{18} + 3 \sqrt{8} = 2 \times 3 \sqrt{2} + 3 \times 2 \sqrt{2} = 12 \sqrt{2}.$$

# %%
2*sm.sqrt(18) + 3*sm.sqrt(8)
# Out:
# 12*sqrt(2)

# %% [markdown]
# ### Continued Fraciones

# %% [markdown]
# #Construimos fracciones continuadas de la forma
#
# <font size="12">
# \begin{eqnarray}
# a_0 + \frac{x}{  a_1 + \frac{x}{ a_2 + \frac{x}{a_3 + \frac{x}{a_4 + \frac{x}{a_5 + \cdots }}}}}
# \end{eqnarray}
# </font>

# %%
from sympy  import symbols
a = symbols('a0:6')
a
# Out:
# (a0, a1, a2, a3, a4, a5)

# %%
x= symbols('x')

# %%
def continued_fraction(depth):
    frac = a[0]
    for d in range(depth):
        frac = frac.replace( a[d], a[d] + x/a[d+1])
    return frac

# %%
cf = continued_fraction(5)
cf
# Out:
# a0 + x/(a1 + x/(a2 + x/(a3 + x/(a4 + x/a5))))

# %% [markdown]
# Si quiere converetir la anterior expresion a LaTeX lo puede hacer

# %%
sm.latex(cf)
# Out:
# 'a_{0} + \\frac{x}{a_{1} + \\frac{x}{a_{2} + \\frac{x}{a_{3} + \\frac{x}{a_{4} + \\frac{x}{a_{5}}}}}}'

# %% [markdown]
# $$ u=a_{0} + \frac{x}{a_{1} + \frac{x}{a_{2} + \frac{x}{a_{3} + \frac{x}{a_{4} + \frac{x}{a_{5}}}}}} .$$

# %% [markdown]
# ### Convertir de sympy format a latex format
# # Actividad 2:
#  Por que cuando convertimos de sympy a latex salieron dobles "\\" .
# Averiguar como hacer para que la instruccion le genere solo un slash. Y verificar que el resultado es correcto.

# %% [markdown]
# ### En la proxima clase:
#
# * aplicacion de fracciones continuadas para estimar $\pi$ el GoldenRatio $\phi$, etc.
#
# * Formas de mostrar numeros con distintass cifras decimales.
# * Precision
#
# * Segundo tema **Algebra I**
