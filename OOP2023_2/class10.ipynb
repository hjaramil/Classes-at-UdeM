# %% [markdown]
# # Proyecto #1

# %%
a=5
b=6

# %%
pwd  # path word
# Out:
# '/content'

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
# !pwd
# Out:
# /content/sample_data

# %%
# !cd ..
# !pwd
# Out:
# /content/sample_data

# %%
# !pwd
# Out:
# /content/sample_data

# %%
# !cd ..
# !pwd
# Out:
# /content/sample_data

# %%
cd /content/
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
import sys
sys.path.append('./sample_data')
import cuaderno

# %%
from cuaderno import Nota, Cuaderno
n = Cuaderno() # objeto n de clase Cuaderno
n.notaNueva("Hola mundo")
n.notaNueva("Hola otra vez")
n.notas
# Out:
# [<cuaderno.Nota at 0x7c0b4427f9d0>, <cuaderno.Nota at 0x7c0b4427f940>]

# %%
n.notas[0].id
# Out:
# 0

# %%
n.notas[1].id
# Out:
# 1

# %%
n.notas[2].id
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-076c292ef9db> in <cell line: 1>()
# ----> 1 n.notas[2].id
#
# IndexError: list index out of range

# %%
n.notas[0].memo
# Out:
# 'Hola mundo'

# %%
n.busque("Hola")
# Out:
# [<cuaderno.Nota at 0x7c0b4427f9d0>, <cuaderno.Nota at 0x7c0b4427f940>]

# %%
# modificar
n.modifiqueMemo(1, "hi world")
n.notas[1].memo
# Out:
# 'hi world'

# %%
n.busque("Hola")

# %%
n.notaNueva("con etiqueta", "Pedro")
n.notas

# %%
vars(n.notas[0])
# Out:
# {'memo': 'Hola mundo',
#  'etiqueta': '',
#  'fechaDeCreado': datetime.date(2023, 8, 24),
#  'id': 0}

# %%
vars(n.notas[2])
# Out:
# {'memo': 'con etiqueta',
#  'etiqueta': 'Pedro',
#  'fechaDeCreado': datetime.date(2023, 8, 24),
#  'id': 2}

# %%
n.notas[2].etiqueta
# Out:
# 'Pedro'

# %%
# busqueda
n.encuentreNota(3)
# Out:
# no se encontro la nota 3

# %%
n2 = n.encuentreNota(2)
vars(n2)
# Out:
# {'memo': 'con etiqueta',
#  'etiqueta': 'Pedro',
#  'fechaDeCreado': datetime.date(2023, 8, 24),
#  'id': 2}

# %%
n3= n.busque("Pedro")
print(n3)

# %%
type(n3)
# Out:
# list

# %%
vars(n3[0])
# Out:
# {'memo': 'con etiqueta',
#  'etiqueta': 'Pedro',
#  'fechaDeCreado': datetime.date(2023, 8, 24),
#  'id': 2}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-45c396b49ded> in <cell line: 1>()
# ----> 1 vars(n3)
#
# TypeError: vars() argument must have __dict__ attribute

# %%
n.modifiqueEtiqueta(2, "Juan")
n.notas[2].etiqueta
# Out:
# 'Juan'

# %%
n.notas

# %%
for nota in n.notas:
    print(vars(nota))
# Out:
# {'memo': 'Hola mundo', 'etiqueta': '', 'fechaDeCreado': datetime.date(2023, 8, 24), 'id': 0}
# {'memo': 'hi world', 'etiqueta': '', 'fechaDeCreado': datetime.date(2023, 8, 24), 'id': 1}
# {'memo': 'con etiqueta', 'etiqueta': 'Juan', 'fechaDeCreado': datetime.date(2023, 8, 24), 'id': 2}

# %%
# imprima usando la funcion
n.imprimaNotas()
# Out:
# {'memo': 'Hola mundo', 'etiqueta': '', 'fechaDeCreado': datetime.date(2023, 8, 24), 'id': 0}
# {'memo': 'hi world', 'etiqueta': '', 'fechaDeCreado': datetime.date(2023, 8, 24), 'id': 1}
# {'memo': 'con etiqueta', 'etiqueta': 'Juan', 'fechaDeCreado': datetime.date(2023, 8, 24), 'id': 2}
