# %% [markdown]
# # Interacción de Jupyter (Python) con Sistemas operativos
# Python y Jupyter ayudan a simular el sistema operativo en cual usted escoja (y pueda) trabajar. Los dos sistemas mas importantes
# son Unix y Windows. Tanto Linux como MacOS se basan en Unix.
# Lo que esta detras de Windows es el DOS (Disk Operational System).
#
# En esta clase vamos a ver la interaccion entre Jupyter/Python (a traves de Google Colab) y el sistema Linux (Unix).
# Sin embargo si usted quiere ver la interaccion de Jupyter/Python con Windows lo invito a ver
# [esta pagina](https://www.analyticsvidhya.com/blog/2021/05/how-to-interact-with-operating-system-using-python-and-jupyter-notebook/) permite interactuar tu Jupyter(Python) con Windows OS.
#
# Otra de las razones para escoger Unix es por que Google Colab esta montado sobre un sistema Unix

# %% [markdown]
# Para ver el sistema operativo de Google Colab interactivamente haga click en el icono de carpeta  a la izquierda.
#
# Para ver donde estas parados el comando (unix) es
# ```pwd```: print working directoy

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# Si me quiero mover hacia arriba hago
# ```cd .. ```

# %%
pwd
# Out:
# '/'

# %% [markdown]
# El significado e '/' es la raiz del arbol
#
# El comando ```ls``` lista los archivos dentro del "current directory"
#
# El comando ```cd``` cambia directory

# %%
ls
# Out:
# bin@                        etc/     media/                    root/  tools/
# boot/                       home/    mnt/                      run/   usr/
# content/                    lib@     NGC-DL-CONTAINER-LICENSE  sbin@  var/
# cuda-keyring_1.0-1_all.deb  lib32@   opt/                      srv/
# datalab/                    lib64@   proc/                     sys/
# dev/                        libx32@  python-apt/               tmp/

# %%
cd content
# Out:
# /content

# %%
ls
# Out:
# sample_data/

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
ls
# Out:
# anscombe.json*                holaMundo.py           README.md*
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# para ver holaMundo.py use cat
# el signo de admiracion en este caso
# se necesita. Es un "magic"
# lo explico mas adelante en esta o la proxima clase
# cat: concatenation
# !cat holaMundo.py
# Out:
# print("hello world\n")

# %%
ls -lt #l=long, t=tiempo de grabado
# Out:
# total 55508
# -rw-r--r-- 1 root root       22 Oct  3 21:33 holaMundo.py
# -rw-r--r-- 1 root root   301141 Oct  2 13:21 california_housing_test.csv
# -rw-r--r-- 1 root root 18289443 Oct  2 13:21 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Oct  2 13:21 mnist_train_small.csv
# -rw-r--r-- 1 root root  1706430 Oct  2 13:21 california_housing_train.csv
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json*
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md*

# %%
# se necesita el ! por que es un magic
# !python holaMundo.py
# Out:
# hello world

# %% [markdown]
# Los comandos ```more``` y ```less``` son usados para ver el contenido de un archivo. El comando
# ```cat``` no para y muestra todo hasta el final.
# El comando ```more``` lo hace pagina por pagina.

# %%
more holaMundo.py

# %%
less holaMundo.py

# %%
man more

# %%
ls
# Out:
# anscombe.json*                holaMundo.py           README.md*
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
more california_housing_test.csv

# %% [markdown]
# En Unix el caracter "|" (pipe) concatena dos comandos. La salida de el primero es la entrada al segundo.
# Ejemplo:
# El comando
# ```cat california_housing_test.csv | wc```
# funcion asi:
#
# * El comando ```cat california_housing_test.csv``` lista el contenido del archivo a un buffer que usted nove.
# * El buffer del primer comando para a ser la entrada al comando ```wc``` que cuenta las palabras (word count).

# %%
cat california_housing_test.csv | wc
# Out:
#    3001    3001  301141

# %%
ls -lt
# Out:
# total 55512
# -rw-r--r-- 1 root root       25 Oct  3 21:46 sumeAmB.py
# -rw-r--r-- 1 root root       22 Oct  3 21:33 holaMundo.py
# -rw-r--r-- 1 root root   301141 Oct  2 13:21 california_housing_test.csv
# -rw-r--r-- 1 root root 18289443 Oct  2 13:21 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Oct  2 13:21 mnist_train_small.csv
# -rw-r--r-- 1 root root  1706430 Oct  2 13:21 california_housing_train.csv
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json*
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md*

# %%
# !python sumeAmB.py
# Out:
# a+b= 11

# %%
# %run sumeAmB.py
# Out:
# a+b= 11

# %%
ls
# Out:
# anscombe.json*                holaMundo.py           README.md*
# california_housing_test.csv   mnist_test.csv         sumeAmB.py
# california_housing_train.csv  mnist_train_small.csv

# %%
ls cal*
# Out:
# california_housing_test.csv  california_housing_train.csv

# %%
lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
ls cal*
# Out:
# california_housing_test.csv  california_housing_train.csv

# %%
ls *.csv
# Out:
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# !wc *.csv
# Out:
#     3001     3001   301141 california_housing_test.csv
#    17001    17001  1706430 california_housing_train.csv
#    10000    10000 18289443 mnist_test.csv
#    20000    20000 36523880 mnist_train_small.csv
#    50002    50002 56820894 total

# %% [markdown]
# ```wc```: word count: lineas   palabras caracteres

# %%
# !head -n1 california_housing_test.csv # primera linea
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"

# %%
# !head -n2 california_housing_test.csv # las primeras dos lineas
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"
# -122.050000,37.370000,27.000000,3885.000000,661.000000,1537.000000,606.000000,6.608500,344700.000000

# %%
# !wc california_housing_test.csv
# Out:
#   3001   3001 301141 california_housing_test.csv

# %% [markdown]
# ## Interaccion con google drive.
# Use los siguientes comandos

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# anscombe.json*                holaMundo.py           README.md*
# california_housing_test.csv   mnist_test.csv         sumeAmB.py
# california_housing_train.csv  mnist_train_small.csv

# %%
cd ..
# Out:
# /content

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
ls
# Out:
# MyDrive/

# %% [markdown]
# # Proxima clase: Magic things
