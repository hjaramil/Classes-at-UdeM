# %% [markdown]
# # Scope (Alcance)
# Ya habiamos hablado de alcance cuando hablamos de OO en general, pero aca es algo mas espeficico a ```Python```.
#
# El alcance se refiere a la **visibilidad** y **accesibilidad** de variables, metodos, clases. Entender el concepto de alcance es importante para asegurar el buen tratamiento de la encapsulacion, ocultamiento de datos (data hidding), eficiencia y organizacion del codigo.
#
# Veamos el tema con ejemplos.

# %%
# local scope
def areaOfCircle(r):
    # r is the radius
    pi = 3.14159
    print("local variables", locals())
    print("the value of pi is", pi)
    print("the value of r is", r)
    return pi*r**2

print(areaOfCircle(1))
# Out:
# local variables {'r': 1, 'pi': 3.14159}
# the value of pi is 3.14159
# the value of r is 1
# 3.14159

# %%
print(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9e2d2bd32686> in <cell line: 1>()
# ----> 1 print(pi)
#
# NameError: name 'pi' is not defined

# %%
print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c6b8a6a9416b> in <cell line: 1>()
# ----> 1 print(r)
#
# NameError: name 'r' is not defined

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()'],
#  '_oh': {},
#  '_dh': ['/content'],
#  'In': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7adffce02230>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_ii': 'print(r)',
#  '_iii': 'print(pi)',
#  '_i1': '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#  'areaOfCircle': <function __main__.areaOfCircle(r)>,
#  '_i2': '?locals',
#  '_i3': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i4': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i5': 'print(pi)',
#  '_i6': 'print(r)',
#  '_i7': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i8': 'locals()'}

# %% [markdown]
# # Global Scope

# %%
def areaOfCircle(r):
    global pi  # esta es una variable global que se puede ver
    # por fuera de la funcion
    pi=3.14159
    print("locals", locals())
    return pi*r**2

print(areaOfCircle(1))
# Out:
# locals {'r': 1}
# 3.14159

# %%
print(pi)
# Out:
# 3.14159

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'print(pi)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'globals()'],
#  '_oh': {8: {...}},
#  '_dh': ['/content'],
#  'In': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'print(pi)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'globals()'],
#  'Out': {8: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7adffce02230>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '_i': 'print(pi)',
#  '_ii': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_iii': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i1': '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#  'areaOfCircle': <function __main__.areaOfCircle(r)>,
#  '_i2': '?locals',
#  '_i3': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i4': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i5': 'print(pi)',
#  '_i6': 'print(r)',
#  '_i7': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i8': 'locals()',
#  '_8': {...},
#  '_i9': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i10': 'print(pi)',
#  '_i11': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i12': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  'pi': 3.14159,
#  '_i13': 'print(pi)',
#  '_i14': 'globals()'}

# %%
locals()==globals()
# Out:
# True

# %% [markdown]
# ## Built-in scope

# %%
print(True)
# Out:
# True

# %%
print(not True)
# Out:
# False

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemError', 'SystemExit', 'TabError', 'TimeoutError', 'True', 'TypeError', 'UnboundLocalError', 'UnicodeDecodeError', 'UnicodeEncodeError', 'UnicodeError', 'UnicodeTranslateError', 'UnicodeWarning', 'UserWarning', 'ValueError', 'Warning', 'ZeroDivisionError', '__IPYTHON__', '__build_class__', '__debug__', '__doc__', '__import__', '__loader__', '__name__', '__package__', '__spec__', 'abs', 'aiter', 'all', 'anext', 'any', 'ascii', 'bin', 'bool', 'breakpoint', 'bytearray', 'bytes', 'callable', 'chr', 'classmethod', 'compile', 'complex', 'copyright', 'credits', 'delattr', 'dict', 'dir', 'display', 'divmod', 'enumerate', 'eval', 'exec', 'execfile', 'filter', 'float', 'format', 'frozenset', 'get_ipython', 'getattr', 'globals', 'hasattr', 'hash', 'help', 'hex', 'id', 'input', 'int', 'isinstance', 'issubclass', 'iter', 'len', 'license', 'list', 'locals', 'map', 'max', 'memoryview', 'min', 'next', 'object', 'oct', 'open', 'ord', 'pow', 'print', 'property', 'range', 'repr', 'reversed', 'round', 'runfile', 'set', 'setattr', 'slice', 'sorted', 'staticmethod', 'str', 'sum', 'super', 'tuple', 'type', 'vars', 'zip']

# %%
s = dir(__builtins__)
len(s)
# Out:
# 158

# %% [markdown]
# Nota: Es peligroso definir variables importantes como globales por que puede cambiar el significado.

# %%
import numpy as np
pi = np.pi
print("pi=", pi)

def test1():
    global pi
    pi = -1
    return
# Out:
# pi= 3.141592653589793

# %%
test1()

# %%
pi
# Out:
# -1

# %% [markdown]
# Nota 2: No usar nombres reservados para variables,

# %%
AssertionError = 1

# %%
print(AssertionError)
# Out:
# 1

# %% [markdown]
# Hay otros tipo de "scope".
#
# * Class scope
# * Object (instance) scope

# %%
class Cylinder:
    pi = 3.14159

    # las variables locales no son de instancia
    print("\n locals() value inside class\n", locals())

    def __init__(self, radius, base, height):
        self.radius = radius
        self.base = base
        self.height = height
        return

    def volume(self):
        return pi*self.radius**2*self.height
# Out:
#  locals() value inside class
#  {'__module__': '__main__', '__qualname__': 'Cylinder', 'pi': 3.14159}

# %%
myCyl = Cylinder(5,2,3)
myCyl.__dict__
# Out:
# {'radius': 5, 'base': 2, 'height': 3}

# %%
myCyl.radius=6
myCyl.__dict__
# Out:
# {'radius': 6, 'base': 2, 'height': 3}

# %%
myCyl.pi
# Out:
# 3.14159

# %% [markdown]
# # Herramientas de Pyton para estudiar variables y alcance.
#
# * ```locals()```
# * ```globals()```
# * ```dir()```
# * ```vars()```
# * ```%who```

# %%
# mas ejemplos de locals y globals
def areaOfCircle(r):
    pi = 3.14159
    display("locals", locals())
    print("\n\n")
    display("globals", globals())
    return pi*r**2

r=2
print("\n\narea del circulo de radio r=%2.4f is %f\n"%(r, areaOfCircle(r)))
# Out:
# 'locals'
# {'r': 2, 'pi': 3.14159}
# 'globals'
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'print(pi)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'globals()',
#   'locals()==globals()',
#   'print(True)',
#   'print(not True)',
#   'print(__dir(__builtins__))',
#   'print(dir(__builtins__))',
#   's = dir(__builtins__)\nlen(s)',
#   'import numpy as np\npi = np.pi\nprint("pi=", pi)\n\ndef test1():\n    global pi\n    pi = -1\n    return',
#   'test1()',
#   '_pi',
#   'pi',
#   'AssertionError = 1',
#   'print(AssertionError)',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#   'myCyl.radius=6\nmyCyl.__dict__',
#   'myCyl.pi',
#   "get_ipython().run_line_magic('ls', '')",
#   "get_ipython().run_line_magic('ls', '')",
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, areaOfCircle(r)))'],
#  '_oh': {8: {...},
#   14: {...},
#   15: True,
#   20: 158,
#   24: -1,
#   29: {'radius': 6, 'base': 2, 'height': 3},
#   30: {'radius': 6, 'base': 2, 'height': 3},
#   31: 3.14159},
#  '_dh': ['/content'],
#  'In': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'print(pi)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'globals()',
#   'locals()==globals()',
#   'print(True)',
#   'print(not True)',
#   'print(__dir(__builtins__))',
#   'print(dir(__builtins__))',
#   's = dir(__builtins__)\nlen(s)',
#   'import numpy as np\npi = np.pi\nprint("pi=", pi)\n\ndef test1():\n    global pi\n    pi = -1\n    return',
#   'test1()',
#   '_pi',
#   'pi',
#   'AssertionError = 1',
#   'print(AssertionError)',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#   'myCyl.radius=6\nmyCyl.__dict__',
#   'myCyl.pi',
#   "get_ipython().run_line_magic('ls', '')",
#   "get_ipython().run_line_magic('ls', '')",
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, areaOfCircle(r)))'],
#  'Out': {8: {...},
#   14: {...},
#   15: True,
#   20: 158,
#   24: -1,
#   29: {'radius': 6, 'base': 2, 'height': 3},
#   30: {'radius': 6, 'base': 2, 'height': 3},
#   31: 3.14159},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7adffce02230>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  '_': 3.14159,
#  '__': {'radius': 6, 'base': 2, 'height': 3},
#  '___': {'radius': 6, 'base': 2, 'height': 3},
#  '_i': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#  '_ii': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#  '_iii': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaCircle(r)))',
#  '_i1': '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#  'areaOfCircle': <function __main__.areaOfCircle(r)>,
#  '_i2': '?locals',
#  '_i3': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i4': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i5': 'print(pi)',
#  '_i6': 'print(r)',
#  '_i7': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i8': 'locals()',
#  '_8': {...},
#  '_i9': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i10': 'print(pi)',
#  '_i11': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i12': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  'pi': -1,
#  '_i13': 'print(pi)',
#  '_i14': 'globals()',
#  '_14': {...},
#  '_i15': 'locals()==globals()',
#  '_15': True,
#  '_i16': 'print(True)',
#  '_i17': 'print(not True)',
#  '_i18': 'print(__dir(__builtins__))',
#  '_i19': 'print(dir(__builtins__))',
#  '_i20': 's = dir(__builtins__)\nlen(s)',
#  's': ['ArithmeticError',
#   'AssertionError',
#   'AttributeError',
#   'BaseException',
#   'BlockingIOError',
#   'BrokenPipeError',
#   'BufferError',
#   'BytesWarning',
#   'ChildProcessError',
#   'ConnectionAbortedError',
#   'ConnectionError',
#   'ConnectionRefusedError',
#   'ConnectionResetError',
#   'DeprecationWarning',
#   'EOFError',
#   'Ellipsis',
#   'EncodingWarning',
#   'EnvironmentError',
#   'Exception',
#   'False',
#   'FileExistsError',
#   'FileNotFoundError',
#   'FloatingPointError',
#   'FutureWarning',
#   'GeneratorExit',
#   'IOError',
#   'ImportError',
#   'ImportWarning',
#   'IndentationError',
#   'IndexError',
#   'InterruptedError',
#   'IsADirectoryError',
#   'KeyError',
#   'KeyboardInterrupt',
#   'LookupError',
#   'MemoryError',
#   'ModuleNotFoundError',
#   'NameError',
#   'None',
#   'NotADirectoryError',
#   'NotImplemented',
#   'NotImplementedError',
#   'OSError',
#   'OverflowError',
#   'PendingDeprecationWarning',
#   'PermissionError',
#   'ProcessLookupError',
#   'RecursionError',
#   'ReferenceError',
#   'ResourceWarning',
#   'RuntimeError',
#   'RuntimeWarning',
#   'StopAsyncIteration',
#   'StopIteration',
#   'SyntaxError',
#   'SyntaxWarning',
#   'SystemError',
#   'SystemExit',
#   'TabError',
#   'TimeoutError',
#   'True',
#   'TypeError',
#   'UnboundLocalError',
#   'UnicodeDecodeError',
#   'UnicodeEncodeError',
#   'UnicodeError',
#   'UnicodeTranslateError',
#   'UnicodeWarning',
#   'UserWarning',
#   'ValueError',
#   'Warning',
#   'ZeroDivisionError',
#   '__IPYTHON__',
#   '__build_class__',
#   '__debug__',
#   '__doc__',
#   '__import__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   'abs',
#   'aiter',
#   'all',
#   'anext',
#   'any',
#   'ascii',
#   'bin',
#   'bool',
#   'breakpoint',
#   'bytearray',
#   'bytes',
#   'callable',
#   'chr',
#   'classmethod',
#   'compile',
#   'complex',
#   'copyright',
#   'credits',
#   'delattr',
#   'dict',
#   'dir',
#   'display',
#   'divmod',
#   'enumerate',
#   'eval',
#   'exec',
#   'execfile',
#   'filter',
#   'float',
#   'format',
#   'frozenset',
#   'get_ipython',
#   'getattr',
#   'globals',
#   'hasattr',
#   'hash',
#   'help',
#   'hex',
#   'id',
#   'input',
#   'int',
#   'isinstance',
#   'issubclass',
#   'iter',
#   'len',
#   'license',
#   'list',
#   'locals',
#   'map',
#   'max',
#   'memoryview',
#   'min',
#   'next',
#   'object',
#   'oct',
#   'open',
#   'ord',
#   'pow',
#   'print',
#   'property',
#   'range',
#   'repr',
#   'reversed',
#   'round',
#   'runfile',
#   'set',
#   'setattr',
#   'slice',
#   'sorted',
#   'staticmethod',
#   'str',
#   'sum',
#   'super',
#   'tuple',
#   'type',
#   'vars',
#   'zip'],
#  '_20': 158,
#  '_i21': 'import numpy as np\npi = np.pi\nprint("pi=", pi)\n\ndef test1():\n    global pi\n    pi = -1\n    return',
#  'np': <module 'numpy' from '/usr/local/lib/python3.10/dist-packages/numpy/__init__.py'>,
#  'test1': <function __main__.test1()>,
#  '_i22': 'test1()',
#  '_i23': '_pi',
#  '_i24': 'pi',
#  '_24': -1,
#  '_i25': 'AssertionError = 1',
#  'AssertionError': 1,
#  '_i26': 'print(AssertionError)',
#  '_i27': 'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#  'Cylinder': __main__.Cylinder,
#  '_i28': 'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#  '_i29': 'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#  'myCyl': <__main__.Cylinder at 0x7adfb950f400>,
#  '_29': {'radius': 6, 'base': 2, 'height': 3},
#  '_i30': 'myCyl.radius=6\nmyCyl.__dict__',
#  '_30': {'radius': 6, 'base': 2, 'height': 3},
#  '_i31': 'myCyl.pi',
#  '_31': 3.14159,
#  '_i32': 'ls',
#  '_exit_code': 0,
#  '_i33': '%ls',
#  '_i34': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaCircle(r)))',
#  'r': 2,
#  '_i35': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#  '_i36': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#  '_i37': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, areaOfCircle(r)))'}
# area del circulo de radio r=2.0000 is 12.566360

# %%
# por fuera de funciones locals()==globals()
locals()==globals()
# Out:
# True

# %%
# por fuera de funciones locals()==vars()
locals() == vars()
# Out:
# True

# %% [markdown]
# ## ```vars()``` y ```dir()``` sin argumentos

# %%
from pprint import pprint
pprint(vars())
# Out:
# {'AssertionError': 1,
#  'Cylinder': <class '__main__.Cylinder'>,
#  'In': ['',
#         '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    ',
#         "get_ipython().run_line_magic('pinfo', 'locals')",
#         '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    # r is the radius\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle)',
#         '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    # r is the radius\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle(1))',
#         'print(pi)',
#         'print(r)',
#         '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    # r is the radius\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    print("the value of pi is", pi)\n'
#         '    print("the value of r is", r)\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle(1))',
#         'locals()',
#         'def areaOfCircle(r):\n'
#         '    global pi  # esta es una variable global que se puede ver \n'
#         '    # por fuera de la funcion\n'
#         '    pi=3.14159\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle)',
#         'print(pi)',
#         'def areaOfCircle(r):\n'
#         '    global pi  # esta es una variable global que se puede ver \n'
#         '    # por fuera de la funcion\n'
#         '    pi=3.14159\n'
#         '    print("locals", locals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle)',
#         'def areaOfCircle(r):\n'
#         '    global pi  # esta es una variable global que se puede ver \n'
#         '    # por fuera de la funcion\n'
#         '    pi=3.14159\n'
#         '    print("locals", locals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle(1))',
#         'print(pi)',
#         'globals()',
#         'locals()==globals()',
#         'print(True)',
#         'print(not True)',
#         'print(__dir(__builtins__))',
#         'print(dir(__builtins__))',
#         's = dir(__builtins__)\nlen(s)',
#         'import numpy as np\n'
#         'pi = np.pi\n'
#         'print("pi=", pi)\n'
#         '\n'
#         'def test1():\n'
#         '    global pi\n'
#         '    pi = -1\n'
#         '    return',
#         'test1()',
#         '_pi',
#         'pi',
#         'AssertionError = 1',
#         'print(AssertionError)',
#         'class Cylinder:\n'
#         '    pi = 3.14159\n'
#         '\n'
#         '    # las variables locales no son de instancia\n'
#         '    print("\\n locals() value inside class\\n", locals())\n'
#         '\n'
#         '    def __init__(self, radius, base, height):\n'
#         '        self.radius = radius\n'
#         '        self.base = base\n'
#         '        self.height = height\n'
#         '        return\n'
#         '\n'
#         '    def volume(self):\n'
#         '        return pi*self.radius**2*self.height\n'
#         '\n'
#         '        ',
#         'class Cylinder:\n'
#         '    pi = 3.14159\n'
#         '\n'
#         '    # las variables locales no son de instancia\n'
#         '    print("\\n locals() value inside class\\n", locals())\n'
#         '\n'
#         '    def __init__(self, radius, base, height):\n'
#         '        self.radius = radius\n'
#         '        self.base = base\n'
#         '        self.height = height\n'
#         '        return\n'
#         '\n'
#         '    def volume(self):\n'
#         '        return pi*self.radius**2*self.height\n'
#         '\n'
#         '        ',
#         'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#         'myCyl.radius=6\nmyCyl.__dict__',
#         'myCyl.pi',
#         "get_ipython().run_line_magic('ls', '')",
#         "get_ipython().run_line_magic('ls', '')",
#         '# mas ejemplos de locals y globals\n'
#         'def areaOfCircle(r):\n'
#         '    pi = 3.14159\n'
#         '    display("locals", locals())\n'
#         '    print("\\n\\n")\n'
#         '    display("globals", globals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'r=2\n'
#         'print("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, '
#         'areaCircle(r)))',
#         '# mas ejemplos de locals y globals\n'
#         'def areaOfCircle(r):\n'
#         '    pi = 3.14159\n'
#         '    display("locals", locals())\n'
#         '    print("\\n\\n")\n'
#         '    display("globals", globals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'r=2\n'
#         'print("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, '
#         'areaOfCircle(r)))',
#         '# mas ejemplos de locals y globals\n'
#         'def areaOfCircle(r):\n'
#         '    pi = 3.14159\n'
#         '    display("locals", locals())\n'
#         '    print("\\n\\n")\n'
#         '    display("globals", globals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'r=2\n'
#         'print("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, '
#         'areaOfCircle(r)))',
#         '# mas ejemplos de locals y globals\n'
#         'def areaOfCircle(r):\n'
#         '    pi = 3.14159\n'
#         '    display("locals", locals())\n'
#         '    print("\\n\\n")\n'
#         '    display("globals", globals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'r=2\n'
#         'print("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, '
#         'areaOfCircle(r)))',
#         '# por fuera de funciones locals()==globals()\nlocals()==globals()',
#         '# por fuera de funciones locals()==vars()\nlocals() == vars()',
#         'from pprint import pprint\npprint(vars))',
#         'from pprint import pprint\npprint(vars)',
#         'vars()',
#         'pprint(dir)',
#         'pprint(dir())',
#         'from pprint import pprint\npprint(vars())'],
#  'Out': {8: <Recursion on dict with id=135102439757504>,
#          14: <Recursion on dict with id=135102439757504>,
#          15: True,
#          20: 158,
#          24: -1,
#          29: {'base': 2, 'height': 3, 'radius': 6},
#          30: {'base': 2, 'height': 3, 'radius': 6},
#          31: 3.14159,
#          38: True,
#          39: True,
#          42: <Recursion on dict with id=135102439757504>},
#  '_': <Recursion on dict with id=135102439757504>,
#  '_14': <Recursion on dict with id=135102439757504>,
#  '_15': True,
#  '_20': 158,
#  '_24': -1,
#  '_29': {'base': 2, 'height': 3, 'radius': 6},
#  '_30': {'base': 2, 'height': 3, 'radius': 6},
#  '_31': 3.14159,
#  '_38': True,
#  '_39': True,
#  '_42': <Recursion on dict with id=135102439757504>,
#  '_8': <Recursion on dict with id=135102439757504>,
#  '__': True,
#  '___': True,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['/content'],
#  '_exit_code': 0,
#  '_i': 'pprint(dir())',
#  '_i1': '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    ',
#  '_i10': 'print(pi)',
#  '_i11': 'def areaOfCircle(r):\n'
#          '    global pi  # esta es una variable global que se puede ver \n'
#          '    # por fuera de la funcion\n'
#          '    pi=3.14159\n'
#          '    print("locals", locals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle)',
#  '_i12': 'def areaOfCircle(r):\n'
#          '    global pi  # esta es una variable global que se puede ver \n'
#          '    # por fuera de la funcion\n'
#          '    pi=3.14159\n'
#          '    print("locals", locals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle(1))',
#  '_i13': 'print(pi)',
#  '_i14': 'globals()',
#  '_i15': 'locals()==globals()',
#  '_i16': 'print(True)',
#  '_i17': 'print(not True)',
#  '_i18': 'print(__dir(__builtins__))',
#  '_i19': 'print(dir(__builtins__))',
#  '_i2': '?locals',
#  '_i20': 's = dir(__builtins__)\nlen(s)',
#  '_i21': 'import numpy as np\n'
#          'pi = np.pi\n'
#          'print("pi=", pi)\n'
#          '\n'
#          'def test1():\n'
#          '    global pi\n'
#          '    pi = -1\n'
#          '    return',
#  '_i22': 'test1()',
#  '_i23': '_pi',
#  '_i24': 'pi',
#  '_i25': 'AssertionError = 1',
#  '_i26': 'print(AssertionError)',
#  '_i27': 'class Cylinder:\n'
#          '    pi = 3.14159\n'
#          '\n'
#          '    # las variables locales no son de instancia\n'
#          '    print("\\n locals() value inside class\\n", locals())\n'
#          '\n'
#          '    def __init__(self, radius, base, height):\n'
#          '        self.radius = radius\n'
#          '        self.base = base\n'
#          '        self.height = height\n'
#          '        return\n'
#          '\n'
#          '    def volume(self):\n'
#          '        return pi*self.radius**2*self.height\n'
#          '\n'
#          '        ',
#  '_i28': 'class Cylinder:\n'
#          '    pi = 3.14159\n'
#          '\n'
#          '    # las variables locales no son de instancia\n'
#          '    print("\\n locals() value inside class\\n", locals())\n'
#          '\n'
#          '    def __init__(self, radius, base, height):\n'
#          '        self.radius = radius\n'
#          '        self.base = base\n'
#          '        self.height = height\n'
#          '        return\n'
#          '\n'
#          '    def volume(self):\n'
#          '        return pi*self.radius**2*self.height\n'
#          '\n'
#          '        ',
#  '_i29': 'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#  '_i3': '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    # r is the radius\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle)',
#  '_i30': 'myCyl.radius=6\nmyCyl.__dict__',
#  '_i31': 'myCyl.pi',
#  '_i32': 'ls',
#  '_i33': '%ls',
#  '_i34': '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, '
#          'areaCircle(r)))',
#  '_i35': '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, '
#          'areaOfCircle(r)))',
#  '_i36': '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, '
#          'areaOfCircle(r)))',
#  '_i37': '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, '
#          'areaOfCircle(r)))',
#  '_i38': '# por fuera de funciones locals()==globals()\nlocals()==globals()',
#  '_i39': '# por fuera de funciones locals()==vars()\nlocals() == vars()',
#  '_i4': '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    # r is the radius\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle(1))',
#  '_i40': 'from pprint import pprint\npprint(vars))',
#  '_i41': 'from pprint import pprint\npprint(vars)',
#  '_i42': 'vars()',
#  '_i43': 'pprint(dir)',
#  '_i44': 'pprint(dir())',
#  '_i45': 'from pprint import pprint\npprint(vars())',
#  '_i5': 'print(pi)',
#  '_i6': 'print(r)',
#  '_i7': '# local scope\n'
#         'def areaOfCircle(r):\n'
#         '    # r is the radius\n'
#         '    pi = 3.14159\n'
#         '    print("local variables", locals())\n'
#         '    print("the value of pi is", pi)\n'
#         '    print("the value of r is", r)\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle(1))',
#  '_i8': 'locals()',
#  '_i9': 'def areaOfCircle(r):\n'
#         '    global pi  # esta es una variable global que se puede ver \n'
#         '    # por fuera de la funcion\n'
#         '    pi=3.14159\n'
#         '    return pi*r**2\n'
#         '\n'
#         'print(areaOfCircle)',
#  '_ih': ['',
#          '# local scope\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    print("local variables", locals())\n'
#          '    ',
#          "get_ipython().run_line_magic('pinfo', 'locals')",
#          '# local scope\n'
#          'def areaOfCircle(r):\n'
#          '    # r is the radius\n'
#          '    pi = 3.14159\n'
#          '    print("local variables", locals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle)',
#          '# local scope\n'
#          'def areaOfCircle(r):\n'
#          '    # r is the radius\n'
#          '    pi = 3.14159\n'
#          '    print("local variables", locals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle(1))',
#          'print(pi)',
#          'print(r)',
#          '# local scope\n'
#          'def areaOfCircle(r):\n'
#          '    # r is the radius\n'
#          '    pi = 3.14159\n'
#          '    print("local variables", locals())\n'
#          '    print("the value of pi is", pi)\n'
#          '    print("the value of r is", r)\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle(1))',
#          'locals()',
#          'def areaOfCircle(r):\n'
#          '    global pi  # esta es una variable global que se puede ver \n'
#          '    # por fuera de la funcion\n'
#          '    pi=3.14159\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle)',
#          'print(pi)',
#          'def areaOfCircle(r):\n'
#          '    global pi  # esta es una variable global que se puede ver \n'
#          '    # por fuera de la funcion\n'
#          '    pi=3.14159\n'
#          '    print("locals", locals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle)',
#          'def areaOfCircle(r):\n'
#          '    global pi  # esta es una variable global que se puede ver \n'
#          '    # por fuera de la funcion\n'
#          '    pi=3.14159\n'
#          '    print("locals", locals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'print(areaOfCircle(1))',
#          'print(pi)',
#          'globals()',
#          'locals()==globals()',
#          'print(True)',
#          'print(not True)',
#          'print(__dir(__builtins__))',
#          'print(dir(__builtins__))',
#          's = dir(__builtins__)\nlen(s)',
#          'import numpy as np\n'
#          'pi = np.pi\n'
#          'print("pi=", pi)\n'
#          '\n'
#          'def test1():\n'
#          '    global pi\n'
#          '    pi = -1\n'
#          '    return',
#          'test1()',
#          '_pi',
#          'pi',
#          'AssertionError = 1',
#          'print(AssertionError)',
#          'class Cylinder:\n'
#          '    pi = 3.14159\n'
#          '\n'
#          '    # las variables locales no son de instancia\n'
#          '    print("\\n locals() value inside class\\n", locals())\n'
#          '\n'
#          '    def __init__(self, radius, base, height):\n'
#          '        self.radius = radius\n'
#          '        self.base = base\n'
#          '        self.height = height\n'
#          '        return\n'
#          '\n'
#          '    def volume(self):\n'
#          '        return pi*self.radius**2*self.height\n'
#          '\n'
#          '        ',
#          'class Cylinder:\n'
#          '    pi = 3.14159\n'
#          '\n'
#          '    # las variables locales no son de instancia\n'
#          '    print("\\n locals() value inside class\\n", locals())\n'
#          '\n'
#          '    def __init__(self, radius, base, height):\n'
#          '        self.radius = radius\n'
#          '        self.base = base\n'
#          '        self.height = height\n'
#          '        return\n'
#          '\n'
#          '    def volume(self):\n'
#          '        return pi*self.radius**2*self.height\n'
#          '\n'
#          '        ',
#          'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#          'myCyl.radius=6\nmyCyl.__dict__',
#          'myCyl.pi',
#          "get_ipython().run_line_magic('ls', '')",
#          "get_ipython().run_line_magic('ls', '')",
#          '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, '
#          'areaCircle(r)))',
#          '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, '
#          'areaOfCircle(r)))',
#          '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, '
#          'areaOfCircle(r)))',
#          '# mas ejemplos de locals y globals\n'
#          'def areaOfCircle(r):\n'
#          '    pi = 3.14159\n'
#          '    display("locals", locals())\n'
#          '    print("\\n\\n")\n'
#          '    display("globals", globals())\n'
#          '    return pi*r**2\n'
#          '\n'
#          'r=2\n'
#          'print("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, '
#          'areaOfCircle(r)))',
#          '# por fuera de funciones locals()==globals()\nlocals()==globals()',
#          '# por fuera de funciones locals()==vars()\nlocals() == vars()',
#          'from pprint import pprint\npprint(vars))',
#          'from pprint import pprint\npprint(vars)',
#          'vars()',
#          'pprint(dir)',
#          'pprint(dir())',
#          'from pprint import pprint\npprint(vars())'],
#  '_ii': 'pprint(dir)',
#  '_iii': 'vars()',
#  '_oh': {8: <Recursion on dict with id=135102439757504>,
#          14: <Recursion on dict with id=135102439757504>,
#          15: True,
#          20: 158,
#          24: -1,
#          29: {'base': 2, 'height': 3, 'radius': 6},
#          30: {'base': 2, 'height': 3, 'radius': 6},
#          31: 3.14159,
#          38: True,
#          39: True,
#          42: <Recursion on dict with id=135102439757504>},
#  'areaOfCircle': <function areaOfCircle at 0x7adfb959ab90>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x7adffce027d0>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7adffce02230>>,
#  'myCyl': <__main__.Cylinder object at 0x7adfb950f400>,
#  'np': <module 'numpy' from '/usr/local/lib/python3.10/dist-packages/numpy/__init__.py'>,
#  'pi': -1,
#  'pprint': <function pprint at 0x7ae004dad120>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x7adffce027d0>,
#  'r': 2,
#  's': ['ArithmeticError',
#        'AssertionError',
#        'AttributeError',
#        'BaseException',
#        'BlockingIOError',
#        'BrokenPipeError',
#        'BufferError',
#        'BytesWarning',
#        'ChildProcessError',
#        'ConnectionAbortedError',
#        'ConnectionError',
#        'ConnectionRefusedError',
#        'ConnectionResetError',
#        'DeprecationWarning',
#        'EOFError',
#        'Ellipsis',
#        'EncodingWarning',
#        'EnvironmentError',
#        'Exception',
#        'False',
#        'FileExistsError',
#        'FileNotFoundError',
#        'FloatingPointError',
#        'FutureWarning',
#        'GeneratorExit',
#        'IOError',
#        'ImportError',
#        'ImportWarning',
#        'IndentationError',
#        'IndexError',
#        'InterruptedError',
#        'IsADirectoryError',
#        'KeyError',
#        'KeyboardInterrupt',
#        'LookupError',
#        'MemoryError',
#        'ModuleNotFoundError',
#        'NameError',
#        'None',
#        'NotADirectoryError',
#        'NotImplemented',
#        'NotImplementedError',
#        'OSError',
#        'OverflowError',
#        'PendingDeprecationWarning',
#        'PermissionError',
#        'ProcessLookupError',
#        'RecursionError',
#        'ReferenceError',
#        'ResourceWarning',
#        'RuntimeError',
#        'RuntimeWarning',
#        'StopAsyncIteration',
#        'StopIteration',
#        'SyntaxError',
#        'SyntaxWarning',
#        'SystemError',
#        'SystemExit',
#        'TabError',
#        'TimeoutError',
#        'True',
#        'TypeError',
#        'UnboundLocalError',
#        'UnicodeDecodeError',
#        'UnicodeEncodeError',
#        'UnicodeError',
#        'UnicodeTranslateError',
#        'UnicodeWarning',
#        'UserWarning',
#        'ValueError',
#        'Warning',
#        'ZeroDivisionError',
#        '__IPYTHON__',
#        '__build_class__',
#        '__debug__',
#        '__doc__',
#        '__import__',
#        '__loader__',
#        '__name__',
#        '__package__',
#        '__spec__',
#        'abs',
#        'aiter',
#        'all',
#        'anext',
#        'any',
#        'ascii',
#        'bin',
#        'bool',
#        'breakpoint',
#        'bytearray',
#        'bytes',
#        'callable',
#        'chr',
#        'classmethod',
#        'compile',
#        'complex',
#        'copyright',
#        'credits',
#        'delattr',
#        'dict',
#        'dir',
#        'display',
#        'divmod',
#        'enumerate',
#        'eval',
#        'exec',
#        'execfile',
#        'filter',
#        'float',
#        'format',
#        'frozenset',
#        'get_ipython',
#        'getattr',
#        'globals',
#        'hasattr',
#        'hash',
#        'help',
#        'hex',
#        'id',
#        'input',
#        'int',
#        'isinstance',
#        'issubclass',
#        'iter',
#        'len',
#        'license',
#        'list',
#        'locals',
#        'map',
#        'max',
#        'memoryview',
#        'min',
#        'next',
#        'object',
#        'oct',
#        'open',
#        'ord',
#        'pow',
#        'print',
#        'property',
#        'range',
#        'repr',
#        'reversed',
#        'round',
#        'runfile',
#        'set',
#        'setattr',
#        'slice',
#        'sorted',
#        'staticmethod',
#        'str',
#        'sum',
#        'super',
#        'tuple',
#        'type',
#        'vars',
#        'zip'],
#  'test1': <function test1 at 0x7adfc72d3250>}

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'print(pi)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'globals()',
#   'locals()==globals()',
#   'print(True)',
#   'print(not True)',
#   'print(__dir(__builtins__))',
#   'print(dir(__builtins__))',
#   's = dir(__builtins__)\nlen(s)',
#   'import numpy as np\npi = np.pi\nprint("pi=", pi)\n\ndef test1():\n    global pi\n    pi = -1\n    return',
#   'test1()',
#   '_pi',
#   'pi',
#   'AssertionError = 1',
#   'print(AssertionError)',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#   'myCyl.radius=6\nmyCyl.__dict__',
#   'myCyl.pi',
#   "get_ipython().run_line_magic('ls', '')",
#   "get_ipython().run_line_magic('ls', '')",
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, areaOfCircle(r)))',
#   '# por fuera de funciones locals()==globals()\nlocals()==globals()',
#   '# por fuera de funciones locals()==vars()\nlocals() == vars()',
#   'from pprint import pprint\npprint(vars))',
#   'from pprint import pprint\npprint(vars)',
#   'vars()'],
#  '_oh': {8: {...},
#   14: {...},
#   15: True,
#   20: 158,
#   24: -1,
#   29: {'radius': 6, 'base': 2, 'height': 3},
#   30: {'radius': 6, 'base': 2, 'height': 3},
#   31: 3.14159,
#   38: True,
#   39: True},
#  '_dh': ['/content'],
#  'In': ['',
#   '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#   "get_ipython().run_line_magic('pinfo', 'locals')",
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'print(r)',
#   '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'locals()',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'print(pi)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#   'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#   'print(pi)',
#   'globals()',
#   'locals()==globals()',
#   'print(True)',
#   'print(not True)',
#   'print(__dir(__builtins__))',
#   'print(dir(__builtins__))',
#   's = dir(__builtins__)\nlen(s)',
#   'import numpy as np\npi = np.pi\nprint("pi=", pi)\n\ndef test1():\n    global pi\n    pi = -1\n    return',
#   'test1()',
#   '_pi',
#   'pi',
#   'AssertionError = 1',
#   'print(AssertionError)',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#   'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#   'myCyl.radius=6\nmyCyl.__dict__',
#   'myCyl.pi',
#   "get_ipython().run_line_magic('ls', '')",
#   "get_ipython().run_line_magic('ls', '')",
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#   '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, areaOfCircle(r)))',
#   '# por fuera de funciones locals()==globals()\nlocals()==globals()',
#   '# por fuera de funciones locals()==vars()\nlocals() == vars()',
#   'from pprint import pprint\npprint(vars))',
#   'from pprint import pprint\npprint(vars)',
#   'vars()'],
#  'Out': {8: {...},
#   14: {...},
#   15: True,
#   20: 158,
#   24: -1,
#   29: {'radius': 6, 'base': 2, 'height': 3},
#   30: {'radius': 6, 'base': 2, 'height': 3},
#   31: 3.14159,
#   38: True,
#   39: True},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7adffce02230>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7adffce027d0>,
#  '_': True,
#  '__': True,
#  '___': 3.14159,
#  '_i': 'from pprint import pprint\npprint(vars)',
#  '_ii': 'from pprint import pprint\npprint(vars))',
#  '_iii': '# por fuera de funciones locals()==vars()\nlocals() == vars()',
#  '_i1': '# local scope\ndef areaOfCircle(r):\n    pi = 3.14159\n    print("local variables", locals())\n    ',
#  'areaOfCircle': <function __main__.areaOfCircle(r)>,
#  '_i2': '?locals',
#  '_i3': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i4': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i5': 'print(pi)',
#  '_i6': 'print(r)',
#  '_i7': '# local scope\ndef areaOfCircle(r):\n    # r is the radius\n    pi = 3.14159\n    print("local variables", locals())\n    print("the value of pi is", pi)\n    print("the value of r is", r)\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  '_i8': 'locals()',
#  '_8': {...},
#  '_i9': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i10': 'print(pi)',
#  '_i11': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle)',
#  '_i12': 'def areaOfCircle(r):\n    global pi  # esta es una variable global que se puede ver \n    # por fuera de la funcion\n    pi=3.14159\n    print("locals", locals())\n    return pi*r**2\n\nprint(areaOfCircle(1))',
#  'pi': -1,
#  '_i13': 'print(pi)',
#  '_i14': 'globals()',
#  '_14': {...},
#  '_i15': 'locals()==globals()',
#  '_15': True,
#  '_i16': 'print(True)',
#  '_i17': 'print(not True)',
#  '_i18': 'print(__dir(__builtins__))',
#  '_i19': 'print(dir(__builtins__))',
#  '_i20': 's = dir(__builtins__)\nlen(s)',
#  's': ['ArithmeticError',
#   'AssertionError',
#   'AttributeError',
#   'BaseException',
#   'BlockingIOError',
#   'BrokenPipeError',
#   'BufferError',
#   'BytesWarning',
#   'ChildProcessError',
#   'ConnectionAbortedError',
#   'ConnectionError',
#   'ConnectionRefusedError',
#   'ConnectionResetError',
#   'DeprecationWarning',
#   'EOFError',
#   'Ellipsis',
#   'EncodingWarning',
#   'EnvironmentError',
#   'Exception',
#   'False',
#   'FileExistsError',
#   'FileNotFoundError',
#   'FloatingPointError',
#   'FutureWarning',
#   'GeneratorExit',
#   'IOError',
#   'ImportError',
#   'ImportWarning',
#   'IndentationError',
#   'IndexError',
#   'InterruptedError',
#   'IsADirectoryError',
#   'KeyError',
#   'KeyboardInterrupt',
#   'LookupError',
#   'MemoryError',
#   'ModuleNotFoundError',
#   'NameError',
#   'None',
#   'NotADirectoryError',
#   'NotImplemented',
#   'NotImplementedError',
#   'OSError',
#   'OverflowError',
#   'PendingDeprecationWarning',
#   'PermissionError',
#   'ProcessLookupError',
#   'RecursionError',
#   'ReferenceError',
#   'ResourceWarning',
#   'RuntimeError',
#   'RuntimeWarning',
#   'StopAsyncIteration',
#   'StopIteration',
#   'SyntaxError',
#   'SyntaxWarning',
#   'SystemError',
#   'SystemExit',
#   'TabError',
#   'TimeoutError',
#   'True',
#   'TypeError',
#   'UnboundLocalError',
#   'UnicodeDecodeError',
#   'UnicodeEncodeError',
#   'UnicodeError',
#   'UnicodeTranslateError',
#   'UnicodeWarning',
#   'UserWarning',
#   'ValueError',
#   'Warning',
#   'ZeroDivisionError',
#   '__IPYTHON__',
#   '__build_class__',
#   '__debug__',
#   '__doc__',
#   '__import__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   'abs',
#   'aiter',
#   'all',
#   'anext',
#   'any',
#   'ascii',
#   'bin',
#   'bool',
#   'breakpoint',
#   'bytearray',
#   'bytes',
#   'callable',
#   'chr',
#   'classmethod',
#   'compile',
#   'complex',
#   'copyright',
#   'credits',
#   'delattr',
#   'dict',
#   'dir',
#   'display',
#   'divmod',
#   'enumerate',
#   'eval',
#   'exec',
#   'execfile',
#   'filter',
#   'float',
#   'format',
#   'frozenset',
#   'get_ipython',
#   'getattr',
#   'globals',
#   'hasattr',
#   'hash',
#   'help',
#   'hex',
#   'id',
#   'input',
#   'int',
#   'isinstance',
#   'issubclass',
#   'iter',
#   'len',
#   'license',
#   'list',
#   'locals',
#   'map',
#   'max',
#   'memoryview',
#   'min',
#   'next',
#   'object',
#   'oct',
#   'open',
#   'ord',
#   'pow',
#   'print',
#   'property',
#   'range',
#   'repr',
#   'reversed',
#   'round',
#   'runfile',
#   'set',
#   'setattr',
#   'slice',
#   'sorted',
#   'staticmethod',
#   'str',
#   'sum',
#   'super',
#   'tuple',
#   'type',
#   'vars',
#   'zip'],
#  '_20': 158,
#  '_i21': 'import numpy as np\npi = np.pi\nprint("pi=", pi)\n\ndef test1():\n    global pi\n    pi = -1\n    return',
#  'np': <module 'numpy' from '/usr/local/lib/python3.10/dist-packages/numpy/__init__.py'>,
#  'test1': <function __main__.test1()>,
#  '_i22': 'test1()',
#  '_i23': '_pi',
#  '_i24': 'pi',
#  '_24': -1,
#  '_i25': 'AssertionError = 1',
#  'AssertionError': 1,
#  '_i26': 'print(AssertionError)',
#  '_i27': 'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#  'Cylinder': __main__.Cylinder,
#  '_i28': 'class Cylinder:\n    pi = 3.14159\n\n    # las variables locales no son de instancia\n    print("\\n locals() value inside class\\n", locals())\n\n    def __init__(self, radius, base, height):\n        self.radius = radius\n        self.base = base\n        self.height = height\n        return\n\n    def volume(self):\n        return pi*self.radius**2*self.height\n\n        ',
#  '_i29': 'myCyl = Cylinder(5,2,3)\nmyCyl.__dict__',
#  'myCyl': <__main__.Cylinder at 0x7adfb950f400>,
#  '_29': {'radius': 6, 'base': 2, 'height': 3},
#  '_i30': 'myCyl.radius=6\nmyCyl.__dict__',
#  '_30': {'radius': 6, 'base': 2, 'height': 3},
#  '_i31': 'myCyl.pi',
#  '_31': 3.14159,
#  '_i32': 'ls',
#  '_exit_code': 0,
#  '_i33': '%ls',
#  '_i34': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaCircle(r)))',
#  'r': 2,
#  '_i35': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio %r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#  '_i36': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.1f is %f\\n"%(r, areaOfCircle(r)))',
#  '_i37': '# mas ejemplos de locals y globals\ndef areaOfCircle(r):\n    pi = 3.14159\n    display("locals", locals())\n    print("\\n\\n")\n    display("globals", globals())\n    return pi*r**2\n\nr=2\nprint("\\n\\narea del circulo de radio r=%2.4f is %f\\n"%(r, areaOfCircle(r)))',
#  '_i38': '# por fuera de funciones locals()==globals()\nlocals()==globals()',
#  '_38': True,
#  '_i39': '# por fuera de funciones locals()==vars()\nlocals() == vars()',
#  '_39': True,
#  '_i40': 'from pprint import pprint\npprint(vars))',
#  '_i41': 'from pprint import pprint\npprint(vars)',
#  'pprint': <function pprint.pprint(object, stream=None, indent=1, width=80, depth=None, *, compact=False, sort_dicts=True, underscore_numbers=False)>,
#  '_i42': 'vars()'}

# %%
pprint(dir())
# Out:
# ['AssertionError',
#  'Cylinder',
#  'In',
#  'Out',
#  '_',
#  '_14',
#  '_15',
#  '_20',
#  '_24',
#  '_29',
#  '_30',
#  '_31',
#  '_38',
#  '_39',
#  '_42',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'areaOfCircle',
#  'exit',
#  'get_ipython',
#  'myCyl',
#  'np',
#  'pi',
#  'pprint',
#  'quit',
#  'r',
#  's',
#  'test1']

# %%
class Circle:
    pi = 3.14159

    def __init__(self, r):
        self.r = r
        return

    def areaOfCircle(self):
        print("el area del circulo es" ,self.pi*self.r**2)
        return


C = Circle(4)
C.areaOfCircle()
# Out:
# el area del circulo es 50.26544

# %%
print(4**2*3.14159)
# Out:
# 50.26544

# %%
vars(C)
# Out:
# {'r': 4}

# %%
C.__dict__
# Out:
# {'r': 4}

# %%
vars(C) == C.__dict__
# Out:
# True

# %%
dirC = dir(C)
dirC
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'areaOfCircle',
#  'pi',
#  'r']

# %%
dirObj = dir(object)
dirObj
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
setC = set(dirC)
setO = set(dirObj)

# %%
CintO = setC.intersection(setO)

# %%
CintO == setO
# Out:
# True

# %%
# magic %who
# %who
# Out:
# AssertionError	 C	 CintO	 Circle	 Cylinder	 areaOfCircle	 dirC	 dirObj	 myCyl
# np	 pi	 pprint	 r	 s	 setC	 setO	 test1

# %%
?%who

# %% [markdown]
# El comando ```%who``` muestra todas las variables que **usted** ha definido en su programa. Ademas si usa ```%who argument``` el argumento (que es un tipo) define que variables quiere ver. Es decri, aquellas que tengan el argumento, por ejemplo ```int```, ```str```, etc

# %% [markdown]
# # Proxima clase Exeptions (excepciones)
